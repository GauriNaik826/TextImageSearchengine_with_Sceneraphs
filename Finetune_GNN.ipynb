# %%
# !pip install dgl -f https://data.dgl.ai/wheels/repo.html
# Out:
# Looking in links: https://data.dgl.ai/wheels/repo.html
# Collecting dgl
#   Downloading dgl-2.1.0-cp310-cp310-manylinux1_x86_64.whl.metadata (553 bytes)
# Requirement already satisfied: numpy>=1.14.0 in /usr/local/lib/python3.10/dist-packages (from dgl) (1.26.4)
# Requirement already satisfied: scipy>=1.1.0 in /usr/local/lib/python3.10/dist-packages (from dgl) (1.13.1)
# Requirement already satisfied: networkx>=2.1 in /usr/local/lib/python3.10/dist-packages (from dgl) (3.4.2)
# Requirement already satisfied: requests>=2.19.0 in /usr/local/lib/python3.10/dist-packages (from dgl) (2.32.3)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.10/dist-packages (from dgl) (4.66.6)
# Requirement already satisfied: psutil>=5.8.0 in /usr/local/lib/python3.10/dist-packages (from dgl) (5.9.5)
# Collecting torchdata>=0.5.0 (from dgl)
#   Downloading torchdata-0.9.0-cp310-cp310-manylinux1_x86_64.whl.metadata (5.5 kB)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests>=2.19.0->dgl) (3.4.0)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests>=2.19.0->dgl) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests>=2.19.0->dgl) (2.2.3)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests>=2.19.0->dgl) (2024.8.30)
# Requirement already satisfied: torch>=2 in /usr/local/lib/python3.10/dist-packages (from torchdata>=0.5.0->dgl) (2.5.1+cu121)
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from torch>=2->torchdata>=0.5.0->dgl) (3.16.1)
# Requirement already satisfied: typing-extensions>=4.8.0 in /usr/local/lib/python3.10/dist-packages (from torch>=2->torchdata>=0.5.0->dgl) (4.12.2)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.10/dist-packages (from torch>=2->torchdata>=0.5.0->dgl) (3.1.4)
# Requirement already satisfied: fsspec in /usr/local/lib/python3.10/dist-packages (from torch>=2->torchdata>=0.5.0->dgl) (2024.10.0)
# Requirement already satisfied: sympy==1.13.1 in /usr/local/lib/python3.10/dist-packages (from torch>=2->torchdata>=0.5.0->dgl) (1.13.1)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.10/dist-packages (from sympy==1.13.1->torch>=2->torchdata>=0.5.0->dgl) (1.3.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.10/dist-packages (from jinja2->torch>=2->torchdata>=0.5.0->dgl) (3.0.2)
# Downloading dgl-2.1.0-cp310-cp310-manylinux1_x86_64.whl (8.5 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 8.5/8.5 MB 32.6 MB/s eta 0:00:00
# Downloading torchdata-0.9.0-cp310-cp310-manylinux1_x86_64.whl (2.7 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.7/2.7 MB 45.4 MB/s eta 0:00:00
# Installing collected packages: torchdata, dgl
# Successfully installed dgl-2.1.0 torchdata-0.9.0

# %%
# !pip install dgl==0.9.1 -f https://data.dgl.ai/wheels/repo.html
# Out:
# Looking in links: https://data.dgl.ai/wheels/repo.html
# Collecting dgl==0.9.1
#   Downloading dgl-0.9.1-cp310-cp310-manylinux1_x86_64.whl.metadata (557 bytes)
# Requirement already satisfied: numpy>=1.14.0 in /usr/local/lib/python3.10/dist-packages (from dgl==0.9.1) (1.26.4)
# Requirement already satisfied: scipy>=1.1.0 in /usr/local/lib/python3.10/dist-packages (from dgl==0.9.1) (1.13.1)
# Requirement already satisfied: networkx>=2.1 in /usr/local/lib/python3.10/dist-packages (from dgl==0.9.1) (3.4.2)
# Requirement already satisfied: requests>=2.19.0 in /usr/local/lib/python3.10/dist-packages (from dgl==0.9.1) (2.32.3)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.10/dist-packages (from dgl==0.9.1) (4.66.6)
# Requirement already satisfied: psutil>=5.8.0 in /usr/local/lib/python3.10/dist-packages (from dgl==0.9.1) (5.9.5)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests>=2.19.0->dgl==0.9.1) (3.4.0)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests>=2.19.0->dgl==0.9.1) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests>=2.19.0->dgl==0.9.1) (2.2.3)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests>=2.19.0->dgl==0.9.1) (2024.8.30)
# Downloading dgl-0.9.1-cp310-cp310-manylinux1_x86_64.whl (4.9 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.9/4.9 MB 14.1 MB/s eta 0:00:00
# Installing collected packages: dgl
#   Attempting uninstall: dgl
#     Found existing installation: dgl 2.1.0
#     Uninstalling dgl-2.1.0:
#       Successfully uninstalled dgl-2.1.0
# Successfully installed dgl-0.9.1

# %%
import torch
import torch.nn as nn
import torch.optim as optim
import dgl
from dgl.nn import GraphConv
# Out:
# DGL backend not selected or invalid.  Assuming PyTorch for now.
# Setting the default backend to "pytorch". You can change it in the ~/.dgl/config.json file or export the DGLBACKEND environment variable.  Valid options are: pytorch, mxnet, tensorflow (all lowercase)
# /usr/local/lib/python3.10/dist-packages/dgl/backend/pytorch/sparse.py:104: FutureWarning: `torch.cuda.amp.custom_fwd(args...)` is deprecated. Please use `torch.amp.custom_fwd(args..., device_type='cuda')` instead.
#   @custom_fwd(cast_inputs=th.float16)
# /usr/local/lib/python3.10/dist-packages/dgl/backend/pytorch/sparse.py:128: FutureWarning: `torch.cuda.amp.custom_bwd(args...)` is deprecated. Please use `torch.amp.custom_bwd(args..., device_type='cuda')` instead.
#   def backward(ctx, dZ):
# /usr/local/lib/python3.10/dist-packages/dgl/backend/pytorch/sparse.py:177: FutureWarning: `torch.cuda.amp.custom_fwd(args...)` is deprecated. Please use `torch.amp.custom_fwd(args..., device_type='cuda')` instead.
#   @custom_fwd(cast_inputs=th.float16)
# /usr/local/lib/python3.10/dist-packages/dgl/backend/pytorch/sparse.py:207: FutureWarning: `torch.cuda.amp.custom_bwd(args...)` is deprecated. Please use `torch.amp.custom_bwd(args..., device_type='cuda')` instead.
#   def backward(ctx, *dZ):
# /usr/local/lib/python3.10/dist-packages/dgl/backend/pytorch/sparse.py:287: FutureWarning: `torch.cuda.amp.custom_fwd(args...)` is deprecated. Please use `torch.amp.custom_fwd(args..., device_type='cuda')` instead.
#   @custom_fwd(cast_inputs=th.float16)
# /usr/local/lib/python3.10/dist-packages/dgl/backend/pytorch/sparse.py:304: FutureWarning: `torch.cuda.amp.custom_bwd(args...)` is deprecated. Please use `torch.amp.custom_bwd(args..., device_type='cuda')` instead.
#   def backward(ctx, dZ):
# /usr/local/lib/python3.10/dist-packages/dgl/backend/pytorch/sparse.py:352: FutureWarning: `torch.cuda.amp.custom_fwd(args...)` is deprecated. Please use `torch.amp.custom_fwd(args..., device_type='cuda')` instead.
#   @custom_fwd(cast_inputs=th.float16)
# /usr/local/lib/python3.10/dist-packages/dgl/backend/pytorch/sparse.py:371: FutureWarning: `torch.cuda.amp.custom_bwd(args...)` is deprecated. Please use `torch.amp.custom_bwd(args..., device_type='cuda')` instead.
#   def backward(ctx, *dZ):
# /usr/local/lib/python3.10/dist-packages/dgl/backend/pytorch/sparse.py:431: FutureWarning: `torch.cuda.amp.custom_fwd(args...)` is deprecated. Please use `torch.amp.custom_fwd(args..., device_type='cuda')` instead.
#   @custom_fwd(cast_inputs=th.float16)
# /usr/local/lib/python3.10/dist-packages/dgl/backend/pytorch/sparse.py:467: FutureWarning: `torch.cuda.amp.custom_bwd(args...)` is deprecated. Please use `torch.amp.custom_bwd(args..., device_type='cuda')` instead.
#   def backward(ctx, grad_out):
# /usr/local/lib/python3.10/dist-packages/dgl/backend/pytorch/sparse.py:498: FutureWarning: `torch.cuda.amp.custom_fwd(args...)` is deprecated. Please use `torch.amp.custom_fwd(args..., device_type='cuda')` instead.
#   @custom_fwd(cast_inputs=th.float16)
# /usr/local/lib/python3.10/dist-packages/dgl/backend/pytorch/sparse.py:535: FutureWarning: `torch.cuda.amp.custom_bwd(args...)` is deprecated. Please use `torch.amp.custom_bwd(args..., device_type='cuda')` instead.
#   def backward(ctx, *grad_out):
# /usr/local/lib/python3.10/dist-packages/dgl/backend/pytorch/sparse.py:566: FutureWarning: `torch.cuda.amp.custom_fwd(args...)` is deprecated. Please use `torch.amp.custom_fwd(args..., device_type='cuda')` instead.
#   @custom_fwd(cast_inputs=th.float16)
# /usr/local/lib/python3.10/dist-packages/dgl/backend/pytorch/sparse.py:575: FutureWarning: `torch.cuda.amp.custom_bwd(args...)` is deprecated. Please use `torch.amp.custom_bwd(args..., device_type='cuda')` instead.
#   def backward(ctx, dy):
# /usr/local/lib/python3.10/dist-packages/dgl/backend/pytorch/sparse.py:595: FutureWarning: `torch.cuda.amp.custom_fwd(args...)` is deprecated. Please use `torch.amp.custom_fwd(args..., device_type='cuda')` instead.
#   @custom_fwd(cast_inputs=th.float16)
# /usr/local/lib/python3.10/dist-packages/dgl/backend/pytorch/sparse.py:603: FutureWarning: `torch.cuda.amp.custom_bwd(args...)` is deprecated. Please use `torch.amp.custom_bwd(args..., device_type='cuda')` instead.
#   def backward(ctx, dy):
# /usr/local/lib/python3.10/dist-packages/dgl/backend/pytorch/sparse.py:666: FutureWarning: `torch.cuda.amp.custom_fwd(args...)` is deprecated. Please use `torch.amp.custom_fwd(args..., device_type='cuda')` instead.
#   @custom_fwd(cast_inputs=th.float16)
# /usr/local/lib/python3.10/dist-packages/dgl/backend/pytorch/sparse.py:692: FutureWarning: `torch.cuda.amp.custom_fwd(args...)` is deprecated. Please use `torch.amp.custom_fwd(args..., device_type='cuda')` instead.
#   @custom_fwd(cast_inputs=th.float16)

# %% [markdown]
# Define the dataset processing and graph construction

# %%
def process_scene_graph(scene_graph):
    """
    Convert a scene graph in textual form into nodes and edges.
    """
    nodes = set()
    edges = []
    print("Raw scene_graph:", scene_graph)



    # Parse the scene graph
    for relation in scene_graph:
        print("relation:", relation)
        print("len(relation)",len(relation))
        if len(relation) < 3:
            continue
        for i in range(0,len(relation),3):
            src = relation[i].strip().lstrip("(").strip()
            rel = relation[i + 1].strip().lstrip('v:').strip()
            dst = relation[i + 2].strip().rstrip(")").strip()
            print(f"Processed relation: src = {src}, rel = {rel}, dst = {dst}")
            nodes.add(src)
            nodes.add(dst)
            edges.append((src, rel, dst))

    return list(nodes), edges

def create_dgl_graph(nodes, edges):
    """
    Create a DGL graph from nodes and edges.
    """
    # Map nodes and relations to unique IDs
    print("nodes:", nodes)
    print("edges:", edges)
    node_to_id = {node: i for i, node in enumerate(nodes)}
    print("node_to_id", node_to_id)
    relation_to_id = {rel: i for i, (_, rel, _) in enumerate(edges)}
    print("relation_to_id:", relation_to_id)

    # Prepare source and destination node indices
    src_nodes = [node_to_id[src] for src, _, _ in edges]
    print("src_nodes:", src_nodes)
    dst_nodes = [node_to_id[dst] for _, _, dst in edges]
    print("dst_nodes:", dst_nodes)

    # Create the graph
    g = dgl.graph((src_nodes, dst_nodes), num_nodes=len(nodes))
    print("g (before adding self-loops):", g)

    # Add self-loops to the graph
    g = dgl.add_self_loop(g)
    print("g (after adding self-loops):", g)

    # Update edge features to match the new number of edges
    original_edge_features = [relation_to_id[rel] for _, rel, _ in edges]
    self_loop_features = [-1] * len(nodes)  # Assign default value for self-loops
    all_edge_features = original_edge_features + self_loop_features
    g.edata['relation_type'] = torch.tensor(all_edge_features, dtype=torch.int64)
    print("g with edge data:", g)

    return g, node_to_id, relation_to_id

# %% [markdown]
# Define the GNN model

# %%
class SceneGraphGNN(nn.Module):
    def __init__(self, in_feats, hidden_feats, num_classes):
        super(SceneGraphGNN, self).__init__()
        self.conv1 = GraphConv(in_feats, hidden_feats)  # First GraphConv layer
        self.conv2 = GraphConv(hidden_feats, num_classes)  # Second GraphConv layer
        self.relu = nn.ReLU()  # Activation function (ReLU)

    def forward(self, g, features):
        # Graph Convolutional Layers
        h = self.conv1(g, features)  # Apply first graph convolution
        h = self.relu(h)  # Apply ReLU activation
        h = self.conv2(g, h)  # Apply second graph convolution
        return h  # Return the output features (node embeddings)

# %% [markdown]
# Dataset loader function

# %%
def load_sample(example):

    # Extract scene graph
    scene_graph = example['scene_graph']
    scene_graph = [tuple(rel.strip("()").split(",")) for rel in scene_graph.split("),")]

    # Create nodes and edges
    nodes, edges = process_scene_graph(scene_graph)

    # Create DGL graph
    g, node_to_id, relation_to_id = create_dgl_graph(nodes, edges)

    g.ndata['feat'] = torch.rand(len(nodes), 64)

    target = torch.rand(len(nodes), 512)

    return g, target

# %%
from google.colab import drive
drive.mount('/content/drive')
checkpoint_path = "/content/drive/MyDrive/gnn_checkpoints/model_checkpoint.pth"
# Out:
# Mounted at /content/drive

# %% [markdown]
# Finetuning LOOP

# %%
def train_gnn(dataset, model, epochs=10, lr=0.01):
    optimizer = optim.Adam(model.parameters(), lr=lr)
    loss_fn = nn.CrossEntropyLoss()  # Assuming it's a classification task
    checkpoint_interval=2

    for epoch in range(epochs):
        total_loss = 0
        count = 0  # Reset count for each epoch
        for example in dataset['train']:
            # Load the graph and target
            g, target = load_sample(example)

            # Forward pass
            logits = model(g, g.ndata['feat'])
            print("logits:", logits)

            # Compute loss
            loss = loss_fn(logits, target)

            # Backpropagation
            optimizer.zero_grad()
            loss.backward()
            optimizer.step()

            total_loss += loss.item()

            count += 1
            if count == 50:
                break

        print(f"Epoch {epoch + 1}/{epochs}, Loss: {total_loss:.4f}")

        if (epoch + 1) % checkpoint_interval == 0:
            torch.save({
                'epoch': epoch + 1,
                'model_state_dict': model.state_dict(),
                'optimizer_state_dict': optimizer.state_dict(),
                'loss': total_loss,
            }, checkpoint_path)
            print(f"Checkpoint saved at epoch {epoch + 1}")

# %% [markdown]
# FACTUAL_SCENE_GRAPH_DATASET

# %%
# !pip install datasets
# Out:
# Collecting datasets
#   Downloading datasets-3.1.0-py3-none-any.whl.metadata (20 kB)
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from datasets) (3.16.1)
# Requirement already satisfied: numpy>=1.17 in /usr/local/lib/python3.10/dist-packages (from datasets) (1.26.4)
# Requirement already satisfied: pyarrow>=15.0.0 in /usr/local/lib/python3.10/dist-packages (from datasets) (17.0.0)
# Collecting dill<0.3.9,>=0.3.0 (from datasets)
#   Downloading dill-0.3.8-py3-none-any.whl.metadata (10 kB)
# Requirement already satisfied: pandas in /usr/local/lib/python3.10/dist-packages (from datasets) (2.2.2)
# Requirement already satisfied: requests>=2.32.2 in /usr/local/lib/python3.10/dist-packages (from datasets) (2.32.3)
# Requirement already satisfied: tqdm>=4.66.3 in /usr/local/lib/python3.10/dist-packages (from datasets) (4.66.6)
# Collecting xxhash (from datasets)
#   Downloading xxhash-3.5.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (12 kB)
# Collecting multiprocess<0.70.17 (from datasets)
#   Downloading multiprocess-0.70.16-py310-none-any.whl.metadata (7.2 kB)
# Collecting fsspec<=2024.9.0,>=2023.1.0 (from fsspec[http]<=2024.9.0,>=2023.1.0->datasets)
#   Downloading fsspec-2024.9.0-py3-none-any.whl.metadata (11 kB)
# Requirement already satisfied: aiohttp in /usr/local/lib/python3.10/dist-packages (from datasets) (3.11.2)
# Requirement already satisfied: huggingface-hub>=0.23.0 in /usr/local/lib/python3.10/dist-packages (from datasets) (0.26.2)
# Requirement already satisfied: packaging in /usr/local/lib/python3.10/dist-packages (from datasets) (24.2)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.10/dist-packages (from datasets) (6.0.2)
# Requirement already satisfied: aiohappyeyeballs>=2.3.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets) (2.4.3)
# Requirement already satisfied: aiosignal>=1.1.2 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets) (1.3.1)
# Requirement already satisfied: attrs>=17.3.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets) (24.2.0)
# Requirement already satisfied: frozenlist>=1.1.1 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets) (1.5.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets) (6.1.0)
# Requirement already satisfied: propcache>=0.2.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets) (0.2.0)
# Requirement already satisfied: yarl<2.0,>=1.17.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets) (1.17.2)
# Requirement already satisfied: async-timeout<6.0,>=4.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets) (4.0.3)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /usr/local/lib/python3.10/dist-packages (from huggingface-hub>=0.23.0->datasets) (4.12.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests>=2.32.2->datasets) (3.4.0)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests>=2.32.2->datasets) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests>=2.32.2->datasets) (2.2.3)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests>=2.32.2->datasets) (2024.8.30)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.10/dist-packages (from pandas->datasets) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/dist-packages (from pandas->datasets) (2024.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.10/dist-packages (from pandas->datasets) (2024.2)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/dist-packages (from python-dateutil>=2.8.2->pandas->datasets) (1.16.0)
# Downloading datasets-3.1.0-py3-none-any.whl (480 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 480.6/480.6 kB 18.2 MB/s eta 0:00:00
# Downloading dill-0.3.8-py3-none-any.whl (116 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 116.3/116.3 kB 9.4 MB/s eta 0:00:00
# Downloading fsspec-2024.9.0-py3-none-any.whl (179 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 179.3/179.3 kB 12.9 MB/s eta 0:00:00
# Downloading multiprocess-0.70.16-py310-none-any.whl (134 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 134.8/134.8 kB 11.3 MB/s eta 0:00:00
# Downloading xxhash-3.5.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (194 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 194.1/194.1 kB 15.4 MB/s eta 0:00:00
# Installing collected packages: xxhash, fsspec, dill, multiprocess, datasets
#   Attempting uninstall: fsspec
#     Found existing installation: fsspec 2024.10.0
#     Uninstalling fsspec-2024.10.0:
#       Successfully uninstalled fsspec-2024.10.0
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# gcsfs 2024.10.0 requires fsspec==2024.10.0, but you have fsspec 2024.9.0 which is incompatible.
# Successfully installed datasets-3.1.0 dill-0.3.8 fsspec-2024.9.0 multiprocess-0.70.16 xxhash-3.5.0

# %%
from datasets import load_dataset
from huggingface_hub import login
dataset = load_dataset('lizhuang144/FACTUAL_Scene_Graph_ID')
# Out:
# /usr/local/lib/python3.10/dist-packages/huggingface_hub/utils/_auth.py:94: UserWarning:
# The secret `HF_TOKEN` does not exist in your Colab secrets.
# To authenticate with the Hugging Face Hub, create a token in your settings tab (https://huggingface.co/settings/tokens), set it as secret in your Google Colab and restart your session.
# You will be able to reuse this secret in all of your notebooks.
# Please note that authentication is recommended but still optional to access public models or datasets.
#   warnings.warn(
# README.md:   0%|          | 0.00/96.0 [00:00<?, ?B/s]
# Repo card metadata block was not found. Setting CardData to empty.
# WARNING:huggingface_hub.repocard:Repo card metadata block was not found. Setting CardData to empty.
# FACTUAL_sg_id.csv:   0%|          | 0.00/3.93M [00:00<?, ?B/s]
# Generating train split:   0%|          | 0/40369 [00:00<?, ? examples/s]

# %% [markdown]
# SPLIT DATASET

# %%
len(dataset)
type(dataset)
print(dataset)
# Out:
# DatasetDict({
#     train: Dataset({
#         features: ['image_id', 'region_id', 'caption', 'scene_graph'],
#         num_rows: 40369
#     })
# })

# %%
input_dim = 64  # Input node feature dimension
hidden_dim = 128  # Hidden layer dimension
num_classes = 512  # Number of output classes

# Initialize the model
model = SceneGraphGNN(input_dim, hidden_dim, num_classes)

# Fine-tune the model on the dataset
train_gnn(dataset, model)
# Out:
# Streaming output truncated to the last 5000 lines.
# nodes: ['bears', 'car']
# edges: [('bears', 'with', 'car')]
# node_to_id {'bears': 0, 'car': 1}
# relation_to_id: {'with': 0}
# src_nodes: [0]
# dst_nodes: [1]
# g (before adding self-loops): Graph(num_nodes=2, num_edges=1,
#       ndata_schemes={}
#       edata_schemes={})
# g (after adding self-loops): Graph(num_nodes=2, num_edges=3,
#       ndata_schemes={}
#       edata_schemes={})
# g with edge data: Graph(num_nodes=2, num_edges=3,
#       ndata_schemes={}
#       edata_schemes={'relation_type': Scheme(shape=(), dtype=torch.int64)})
# logits: tensor([[ 0.0693, -0.0340,  0.0373,  ...,  0.0350,  0.0289, -0.0346],
#         [ 0.0693, -0.0340,  0.0373,  ...,  0.0350,  0.0289, -0.0346]],
#        grad_fn=<AddBackward0>)
# Raw scene_graph: [(' wall ', ' is ', ' glass ) ', ' ( wall ', ' at ', ' train platform ')]
# relation: (' wall ', ' is ', ' glass ) ', ' ( wall ', ' at ', ' train platform ')
# len(relation) 6
# Processed relation: src = wall, rel = is, dst = glass
# Processed relation: src = wall, rel = at, dst = train platform
# nodes: ['wall', 'train platform', 'glass']
# edges: [('wall', 'is', 'glass'), ('wall', 'at', 'train platform')]
# node_to_id {'wall': 0, 'train platform': 1, 'glass': 2}
# relation_to_id: {'is': 0, 'at': 1}
# src_nodes: [0, 0]
# dst_nodes: [2, 1]
# g (before adding self-loops): Graph(num_nodes=3, num_edges=2,
#       ndata_schemes={}
#       edata_schemes={})
# g (after adding self-loops): Graph(num_nodes=3, num_edges=5,
#       ndata_schemes={}
#       edata_schemes={})
# g with edge data: Graph(num_nodes=3, num_edges=5,
#       ndata_schemes={}
#       edata_schemes={'relation_type': Scheme(shape=(), dtype=torch.int64)})
# logits: tensor([[ 0.0680, -0.0328,  0.0358,  ...,  0.0368,  0.0293, -0.0381],
#         [ 0.0680, -0.0328,  0.0358,  ...,  0.0368,  0.0293, -0.0381],
#         [ 0.0680, -0.0328,  0.0358,  ...,  0.0368,  0.0293, -0.0381]],
#        grad_fn=<AddBackward0>)
# Raw scene_graph: [(' motorcycle ', ' v:lean against ', ' wall ')]
# relation: (' motorcycle ', ' v:lean against ', ' wall ')
# len(relation) 3
# Processed relation: src = motorcycle, rel = lean against, dst = wall
# nodes: ['wall', 'motorcycle']
# edges: [('motorcycle', 'lean against', 'wall')]
# node_to_id {'wall': 0, 'motorcycle': 1}
# relation_to_id: {'lean against': 0}
# src_nodes: [1]
# dst_nodes: [0]
# g (before adding self-loops): Graph(num_nodes=2, num_edges=1,
#       ndata_schemes={}
#       edata_schemes={})
# g (after adding self-loops): Graph(num_nodes=2, num_edges=3,
#       ndata_schemes={}
#       edata_schemes={})
# g with edge data: Graph(num_nodes=2, num_edges=3,
#       ndata_schemes={}
#       edata_schemes={'relation_type': Scheme(shape=(), dtype=torch.int64)})
# logits: tensor([[ 0.0660, -0.0330,  0.0337,  ...,  0.0380,  0.0295, -0.0421],
#         [ 0.0660, -0.0330,  0.0337,  ...,  0.0380,  0.0295, -0.0421]],
#        grad_fn=<AddBackward0>)
# Raw scene_graph: [(' people ', ' on ', ' sand ')]
# relation: (' people ', ' on ', ' sand ')
# len(relation) 3
# Processed relation: src = people, rel = on, dst = sand
# nodes: ['people', 'sand']
# edges: [('people', 'on', 'sand')]
# node_to_id {'people': 0, 'sand': 1}
# relation_to_id: {'on': 0}
# src_nodes: [0]
# dst_nodes: [1]
# g (before adding self-loops): Graph(num_nodes=2, num_edges=1,
#       ndata_schemes={}
#       edata_schemes={})
# g (after adding self-loops): Graph(num_nodes=2, num_edges=3,
#       ndata_schemes={}
#       edata_schemes={})
# g with edge data: Graph(num_nodes=2, num_edges=3,
#       ndata_schemes={}
#       edata_schemes={'relation_type': Scheme(shape=(), dtype=torch.int64)})
# logits: tensor([[ 0.0632, -0.0331,  0.0317,  ...,  0.0409,  0.0270, -0.0463],
#         [ 0.0632, -0.0331,  0.0317,  ...,  0.0409,  0.0270, -0.0463]],
#        grad_fn=<AddBackward0>)
# Raw scene_graph: [(' wall ', ' in ', ' room ) ', ' ( wall ', ' is ', ' brownish ) ', ' ( wall ', ' is ', ' orange ')]
# relation: (' wall ', ' in ', ' room ) ', ' ( wall ', ' is ', ' brownish ) ', ' ( wall ', ' is ', ' orange ')
# len(relation) 9
# Processed relation: src = wall, rel = in, dst = room
# Processed relation: src = wall, rel = is, dst = brownish
# Processed relation: src = wall, rel = is, dst = orange
# nodes: ['wall', 'orange', 'brownish', 'room']
# edges: [('wall', 'in', 'room'), ('wall', 'is', 'brownish'), ('wall', 'is', 'orange')]
# node_to_id {'wall': 0, 'orange': 1, 'brownish': 2, 'room': 3}
# relation_to_id: {'in': 0, 'is': 2}
# src_nodes: [0, 0, 0]
# dst_nodes: [3, 2, 1]
# g (before adding self-loops): Graph(num_nodes=4, num_edges=3,
#       ndata_schemes={}
#       edata_schemes={})
# g (after adding self-loops): Graph(num_nodes=4, num_edges=7,
#       ndata_schemes={}
#       edata_schemes={})
# g with edge data: Graph(num_nodes=4, num_edges=7,
#       ndata_schemes={}
#       edata_schemes={'relation_type': Scheme(shape=(), dtype=torch.int64)})
# logits: tensor([[ 0.0610, -0.0320,  0.0311,  ...,  0.0439,  0.0256, -0.0483],
#         [ 0.0608, -0.0323,  0.0303,  ...,  0.0439,  0.0254, -0.0489],
#         [ 0.0608, -0.0323,  0.0303,  ...,  0.0439,  0.0254, -0.0489],
#         [ 0.0608, -0.0323,  0.0303,  ...,  0.0439,  0.0254, -0.0489]],
#        grad_fn=<AddBackward0>)
# Raw scene_graph: [(' mirror ', ' v:hang above ', ' sink ')]
# relation: (' mirror ', ' v:hang above ', ' sink ')
# len(relation) 3
# Processed relation: src = mirror, rel = hang above, dst = sink
# nodes: ['sink', 'mirror']
# edges: [('mirror', 'hang above', 'sink')]
# node_to_id {'sink': 0, 'mirror': 1}
# relation_to_id: {'hang above': 0}
# src_nodes: [1]
# dst_nodes: [0]
# g (before adding self-loops): Graph(num_nodes=2, num_edges=1,
#       ndata_schemes={}
#       edata_schemes={})
# g (after adding self-loops): Graph(num_nodes=2, num_edges=3,
#       ndata_schemes={}
#       edata_schemes={})
# g with edge data: Graph(num_nodes=2, num_edges=3,
#       ndata_schemes={}
#       edata_schemes={'relation_type': Scheme(shape=(), dtype=torch.int64)})
# logits: tensor([[ 0.0561, -0.0335,  0.0253,  ...,  0.0467,  0.0221, -0.0532],
#         [ 0.0561, -0.0335,  0.0253,  ...,  0.0467,  0.0221, -0.0532]],
#        grad_fn=<AddBackward0>)
# Raw scene_graph: [(' teddy bear ', ' v:wear ', ' kimono ')]
# relation: (' teddy bear ', ' v:wear ', ' kimono ')
# len(relation) 3
# Processed relation: src = teddy bear, rel = wear, dst = kimono
# nodes: ['teddy bear', 'kimono']
# edges: [('teddy bear', 'wear', 'kimono')]
# node_to_id {'teddy bear': 0, 'kimono': 1}
# relation_to_id: {'wear': 0}
# src_nodes: [0]
# dst_nodes: [1]
# g (before adding self-loops): Graph(num_nodes=2, num_edges=1,
#       ndata_schemes={}
#       edata_schemes={})
# g (after adding self-loops): Graph(num_nodes=2, num_edges=3,
#       ndata_schemes={}
#       edata_schemes={})
# g with edge data: Graph(num_nodes=2, num_edges=3,
#       ndata_schemes={}
#       edata_schemes={'relation_type': Scheme(shape=(), dtype=torch.int64)})
# logits: tensor([[ 0.0531, -0.0337,  0.0225,  ...,  0.0502,  0.0207, -0.0552],
#         [ 0.0531, -0.0337,  0.0225,  ...,  0.0502,  0.0207, -0.0552]],
#        grad_fn=<AddBackward0>)
# Raw scene_graph: [(' train ', ' v:pass through ', ' arch ) ', ' ( bridge ', ' is ', ' stone ) ', ' ( train ', ' v:pass under ', ' bridge ')]
# relation: (' train ', ' v:pass through ', ' arch ) ', ' ( bridge ', ' is ', ' stone ) ', ' ( train ', ' v:pass under ', ' bridge ')
# len(relation) 9
# Processed relation: src = train, rel = pass through, dst = arch
# Processed relation: src = bridge, rel = is, dst = stone
# Processed relation: src = train, rel = pass under, dst = bridge
# nodes: ['stone', 'bridge', 'arch', 'train']
# edges: [('train', 'pass through', 'arch'), ('bridge', 'is', 'stone'), ('train', 'pass under', 'bridge')]
# node_to_id {'stone': 0, 'bridge': 1, 'arch': 2, 'train': 3}
# relation_to_id: {'pass through': 0, 'is': 1, 'pass under': 2}
# src_nodes: [3, 1, 3]
# dst_nodes: [2, 0, 1]
# g (before adding self-loops): Graph(num_nodes=4, num_edges=3,
#       ndata_schemes={}
#       edata_schemes={})
# g (after adding self-loops): Graph(num_nodes=4, num_edges=7,
#       ndata_schemes={}
#       edata_schemes={})
# g with edge data: Graph(num_nodes=4, num_edges=7,
#       ndata_schemes={}
#       edata_schemes={'relation_type': Scheme(shape=(), dtype=torch.int64)})
# logits: tensor([[ 0.0517, -0.0354,  0.0188,  ...,  0.0523,  0.0194, -0.0571],
#         [ 0.0517, -0.0354,  0.0188,  ...,  0.0523,  0.0194, -0.0571],
#         [ 0.0517, -0.0354,  0.0188,  ...,  0.0523,  0.0194, -0.0571],
#         [ 0.0517, -0.0354,  0.0188,  ...,  0.0523,  0.0194, -0.0571]],
#        grad_fn=<AddBackward0>)
# Raw scene_graph: [(' boys ', ' is ', ' 3 ) ', ' ( boys ', ' v:climb ', ' hill ')]
# relation: (' boys ', ' is ', ' 3 ) ', ' ( boys ', ' v:climb ', ' hill ')
# len(relation) 6
# Processed relation: src = boys, rel = is, dst = 3
# Processed relation: src = boys, rel = climb, dst = hill
# nodes: ['boys', 'hill', '3']
# edges: [('boys', 'is', '3'), ('boys', 'climb', 'hill')]
# node_to_id {'boys': 0, 'hill': 1, '3': 2}
# relation_to_id: {'is': 0, 'climb': 1}
# src_nodes: [0, 0]
# dst_nodes: [2, 1]
# g (before adding self-loops): Graph(num_nodes=3, num_edges=2,
#       ndata_schemes={}
#       edata_schemes={})
# g (after adding self-loops): Graph(num_nodes=3, num_edges=5,
#       ndata_schemes={}
#       edata_schemes={})
# g with edge data: Graph(num_nodes=3, num_edges=5,
#       ndata_schemes={}
#       edata_schemes={'relation_type': Scheme(shape=(), dtype=torch.int64)})
# logits: tensor([[ 0.0482, -0.0363,  0.0144,  ...,  0.0529,  0.0182, -0.0593],
#         [ 0.0482, -0.0363,  0.0144,  ...,  0.0529,  0.0182, -0.0593],
#         [ 0.0482, -0.0363,  0.0144,  ...,  0.0529,  0.0182, -0.0593]],
#        grad_fn=<AddBackward0>)
# Raw scene_graph: [(' television set ', ' v:play ', ' baseball game ')]
# relation: (' television set ', ' v:play ', ' baseball game ')
# len(relation) 3
# Processed relation: src = television set, rel = play, dst = baseball game
# nodes: ['television set', 'baseball game']
# edges: [('television set', 'play', 'baseball game')]
# node_to_id {'television set': 0, 'baseball game': 1}
# relation_to_id: {'play': 0}
# src_nodes: [0]
# dst_nodes: [1]
# g (before adding self-loops): Graph(num_nodes=2, num_edges=1,
#       ndata_schemes={}
#       edata_schemes={})
# g (after adding self-loops): Graph(num_nodes=2, num_edges=3,
#       ndata_schemes={}
#       edata_schemes={})
# g with edge data: Graph(num_nodes=2, num_edges=3,
#       ndata_schemes={}
#       edata_schemes={'relation_type': Scheme(shape=(), dtype=torch.int64)})
# logits: tensor([[ 0.0446, -0.0374,  0.0106,  ...,  0.0536,  0.0160, -0.0609],
#         [ 0.0446, -0.0374,  0.0106,  ...,  0.0536,  0.0160, -0.0609]],
#        grad_fn=<AddBackward0>)
# Raw scene_graph: [(' cat ', ' in ', ' sink ')]
# relation: (' cat ', ' in ', ' sink ')
# len(relation) 3
# Processed relation: src = cat, rel = in, dst = sink
# nodes: ['sink', 'cat']
# edges: [('cat', 'in', 'sink')]
# node_to_id {'sink': 0, 'cat': 1}
# relation_to_id: {'in': 0}
# src_nodes: [1]
# dst_nodes: [0]
# g (before adding self-loops): Graph(num_nodes=2, num_edges=1,
#       ndata_schemes={}
#       edata_schemes={})
# g (after adding self-loops): Graph(num_nodes=2, num_edges=3,
#       ndata_schemes={}
#       edata_schemes={})
# g with edge data: Graph(num_nodes=2, num_edges=3,
#       ndata_schemes={}
#       edata_schemes={'relation_type': Scheme(shape=(), dtype=torch.int64)})
# logits: tensor([[ 0.0426, -0.0377,  0.0081,  ...,  0.0531,  0.0135, -0.0606],
#         [ 0.0426, -0.0377,  0.0081,  ...,  0.0531,  0.0135, -0.0606]],
#        grad_fn=<AddBackward0>)
# Raw scene_graph: [(' water ', ' on ', ' ground ')]
# relation: (' water ', ' on ', ' ground ')
# len(relation) 3
# Processed relation: src = water, rel = on, dst = ground
# nodes: ['ground', 'water']
# edges: [('water', 'on', 'ground')]
# node_to_id {'ground': 0, 'water': 1}
# relation_to_id: {'on': 0}
# src_nodes: [1]
# dst_nodes: [0]
# g (before adding self-loops): Graph(num_nodes=2, num_edges=1,
#       ndata_schemes={}
#       edata_schemes={})
# g (after adding self-loops): Graph(num_nodes=2, num_edges=3,
#       ndata_schemes={}
#       edata_schemes={})
# g with edge data: Graph(num_nodes=2, num_edges=3,
#       ndata_schemes={}
#       edata_schemes={'relation_type': Scheme(shape=(), dtype=torch.int64)})
# logits: tensor([[ 0.0423, -0.0377,  0.0058,  ...,  0.0516,  0.0118, -0.0593],
#         [ 0.0423, -0.0377,  0.0058,  ...,  0.0516,  0.0118, -0.0593]],
#        grad_fn=<AddBackward0>)
# Raw scene_graph: [(' buildings ', ' v:line ', ' street ')]
# relation: (' buildings ', ' v:line ', ' street ')
# len(relation) 3
# Processed relation: src = buildings, rel = line, dst = street
# nodes: ['buildings', 'street']
# edges: [('buildings', 'line', 'street')]
# node_to_id {'buildings': 0, 'street': 1}
# relation_to_id: {'line': 0}
# src_nodes: [0]
# dst_nodes: [1]
# g (before adding self-loops): Graph(num_nodes=2, num_edges=1,
#       ndata_schemes={}
#       edata_schemes={})
# g (after adding self-loops): Graph(num_nodes=2, num_edges=3,
#       ndata_schemes={}
#       edata_schemes={})
# g with edge data: Graph(num_nodes=2, num_edges=3,
#       ndata_schemes={}
#       edata_schemes={'relation_type': Scheme(shape=(), dtype=torch.int64)})
# logits: tensor([[ 0.0412, -0.0399,  0.0046,  ...,  0.0500,  0.0088, -0.0595],
#         [ 0.0412, -0.0399,  0.0046,  ...,  0.0500,  0.0088, -0.0595]],
#        grad_fn=<AddBackward0>)
# Raw scene_graph: [(' road ', ' v:have ', ' dirt ) ', ' ( road ', ' v:have ', ' grass ')]
# relation: (' road ', ' v:have ', ' dirt ) ', ' ( road ', ' v:have ', ' grass ')
# len(relation) 6
# Processed relation: src = road, rel = have, dst = dirt
# Processed relation: src = road, rel = have, dst = grass
# nodes: ['dirt', 'road', 'grass']
# edges: [('road', 'have', 'dirt'), ('road', 'have', 'grass')]
# node_to_id {'dirt': 0, 'road': 1, 'grass': 2}
# relation_to_id: {'have': 1}
# src_nodes: [1, 1]
# dst_nodes: [0, 2]
# g (before adding self-loops): Graph(num_nodes=3, num_edges=2,
#       ndata_schemes={}
#       edata_schemes={})
# g (after adding self-loops): Graph(num_nodes=3, num_edges=5,
#       ndata_schemes={}
#       edata_schemes={})
# g with edge data: Graph(num_nodes=3, num_edges=5,
#       ndata_schemes={}
#       edata_schemes={'relation_type': Scheme(shape=(), dtype=torch.int64)})
# logits: tensor([[ 0.0409, -0.0398,  0.0049,  ...,  0.0480,  0.0072, -0.0606],
#         [ 0.0409, -0.0398,  0.0049,  ...,  0.0480,  0.0072, -0.0606],
#         [ 0.0409, -0.0398,  0.0049,  ...,  0.0480,  0.0072, -0.0606]],
#        grad_fn=<AddBackward0>)
# Raw scene_graph: [(' phones ', ' on ', ' table ) ', ' ( phones ', ' is ', ' 3 ')]
# relation: (' phones ', ' on ', ' table ) ', ' ( phones ', ' is ', ' 3 ')
# len(relation) 6
# Processed relation: src = phones, rel = on, dst = table
# Processed relation: src = phones, rel = is, dst = 3
# nodes: ['table', 'phones', '3']
# edges: [('phones', 'on', 'table'), ('phones', 'is', '3')]
# node_to_id {'table': 0, 'phones': 1, '3': 2}
# relation_to_id: {'on': 0, 'is': 1}
# src_nodes: [1, 1]
# dst_nodes: [0, 2]
# g (before adding self-loops): Graph(num_nodes=3, num_edges=2,
#       ndata_schemes={}
#       edata_schemes={})
# g (after adding self-loops): Graph(num_nodes=3, num_edges=5,
#       ndata_schemes={}
#       edata_schemes={})
# g with edge data: Graph(num_nodes=3, num_edges=5,
#       ndata_schemes={}
#       edata_schemes={'relation_type': Scheme(shape=(), dtype=torch.int64)})
# logits: tensor([[ 0.0411, -0.0406,  0.0058,  ...,  0.0477,  0.0051, -0.0610],
#         [ 0.0411, -0.0406,  0.0058,  ...,  0.0477,  0.0051, -0.0610],
#         [ 0.0411, -0.0406,  0.0058,  ...,  0.0477,  0.0051, -0.0610]],
#        grad_fn=<AddBackward0>)
# Raw scene_graph: [(' clock ', ' on ', ' tower ')]
# relation: (' clock ', ' on ', ' tower ')
# len(relation) 3
# Processed relation: src = clock, rel = on, dst = tower
# nodes: ['tower', 'clock']
# edges: [('clock', 'on', 'tower')]
# node_to_id {'tower': 0, 'clock': 1}
# relation_to_id: {'on': 0}
# src_nodes: [1]
# dst_nodes: [0]
# g (before adding self-loops): Graph(num_nodes=2, num_edges=1,
#       ndata_schemes={}
#       edata_schemes={})
# g (after adding self-loops): Graph(num_nodes=2, num_edges=3,
#       ndata_schemes={}
#       edata_schemes={})
# g with edge data: Graph(num_nodes=2, num_edges=3,
#       ndata_schemes={}
#       edata_schemes={'relation_type': Scheme(shape=(), dtype=torch.int64)})
# logits: tensor([[ 0.0409, -0.0411,  0.0068,  ...,  0.0474,  0.0044, -0.0618],
#         [ 0.0409, -0.0411,  0.0068,  ...,  0.0474,  0.0044, -0.0618]],
#        grad_fn=<AddBackward0>)
# Raw scene_graph: [(' motorcycle ', ' in front of ', ' building ) ', ' ( motorcycle ', ' is ', ' parked ')]
# relation: (' motorcycle ', ' in front of ', ' building ) ', ' ( motorcycle ', ' is ', ' parked ')
# len(relation) 6
# Processed relation: src = motorcycle, rel = in front of, dst = building
# Processed relation: src = motorcycle, rel = is, dst = parked
# nodes: ['parked', 'building', 'motorcycle']
# edges: [('motorcycle', 'in front of', 'building'), ('motorcycle', 'is', 'parked')]
# node_to_id {'parked': 0, 'building': 1, 'motorcycle': 2}
# relation_to_id: {'in front of': 0, 'is': 1}
# src_nodes: [2, 2]
# dst_nodes: [1, 0]
# g (before adding self-loops): Graph(num_nodes=3, num_edges=2,
#       ndata_schemes={}
#       edata_schemes={})
# g (after adding self-loops): Graph(num_nodes=3, num_edges=5,
#       ndata_schemes={}
#       edata_schemes={})
# g with edge data: Graph(num_nodes=3, num_edges=5,
#       ndata_schemes={}
#       edata_schemes={'relation_type': Scheme(shape=(), dtype=torch.int64)})
# logits: tensor([[ 0.0397, -0.0413,  0.0075,  ...,  0.0457,  0.0034, -0.0627],
#         [ 0.0397, -0.0413,  0.0075,  ...,  0.0457,  0.0034, -0.0627],
#         [ 0.0397, -0.0413,  0.0075,  ...,  0.0457,  0.0034, -0.0627]],
#        grad_fn=<AddBackward0>)
# Epoch 6/10, Loss: 80148.2488
# Checkpoint saved at epoch 6
# Raw scene_graph: [(' bike ', ' v:rest against ', ' box ')]
# relation: (' bike ', ' v:rest against ', ' box ')
# len(relation) 3
# Processed relation: src = bike, rel = rest against, dst = box
# nodes: ['box', 'bike']
# edges: [('bike', 'rest against', 'box')]
# node_to_id {'box': 0, 'bike': 1}
# relation_to_id: {'rest against': 0}
# src_nodes: [1]
# dst_nodes: [0]
# g (before adding self-loops): Graph(num_nodes=2, num_edges=1,
#       ndata_schemes={}
#       edata_schemes={})
# g (after adding self-loops): Graph(num_nodes=2, num_edges=3,
#       ndata_schemes={}
#       edata_schemes={})
# g with edge data: Graph(num_nodes=2, num_edges=3,
#       ndata_schemes={}
#       edata_schemes={'relation_type': Scheme(shape=(), dtype=torch.int64)})
# logits: tensor([[ 0.0378, -0.0409,  0.0074,  ...,  0.0446,  0.0023, -0.0625],
#         [ 0.0378, -0.0409,  0.0074,  ...,  0.0446,  0.0023, -0.0625]],
#        grad_fn=<AddBackward0>)
# Raw scene_graph: [(' woman ', ' v:hold ', ' umbrella ')]
# relation: (' woman ', ' v:hold ', ' umbrella ')
# len(relation) 3
# Processed relation: src = woman, rel = hold, dst = umbrella
# nodes: ['umbrella', 'woman']
# edges: [('woman', 'hold', 'umbrella')]
# node_to_id {'umbrella': 0, 'woman': 1}
# relation_to_id: {'hold': 0}
# src_nodes: [1]
# dst_nodes: [0]
# g (before adding self-loops): Graph(num_nodes=2, num_edges=1,
#       ndata_schemes={}
#       edata_schemes={})
# g (after adding self-loops): Graph(num_nodes=2, num_edges=3,
#       ndata_schemes={}
#       edata_schemes={})
# g with edge data: Graph(num_nodes=2, num_edges=3,
#       ndata_schemes={}
#       edata_schemes={'relation_type': Scheme(shape=(), dtype=torch.int64)})
# logits: tensor([[ 0.0364, -0.0418,  0.0089,  ...,  0.0452,  0.0004, -0.0607],
#         [ 0.0364, -0.0418,  0.0089,  ...,  0.0452,  0.0004, -0.0607]],
#        grad_fn=<AddBackward0>)
# Raw scene_graph: [(' tree trunk ', ' is ', ' large ) ', ' ( tree trunk ', ' v:come through ', ' deck ')]
# relation: (' tree trunk ', ' is ', ' large ) ', ' ( tree trunk ', ' v:come through ', ' deck ')
# len(relation) 6
# Processed relation: src = tree trunk, rel = is, dst = large
# Processed relation: src = tree trunk, rel = come through, dst = deck
# nodes: ['deck', 'large', 'tree trunk']
# edges: [('tree trunk', 'is', 'large'), ('tree trunk', 'come through', 'deck')]
# node_to_id {'deck': 0, 'large': 1, 'tree trunk': 2}
# relation_to_id: {'is': 0, 'come through': 1}
# src_nodes: [2, 2]
# dst_nodes: [1, 0]
# g (before adding self-loops): Graph(num_nodes=3, num_edges=2,
#       ndata_schemes={}
#       edata_schemes={})
# g (after adding self-loops): Graph(num_nodes=3, num_edges=5,
#       ndata_schemes={}
#       edata_schemes={})
# g with edge data: Graph(num_nodes=3, num_edges=5,
#       ndata_schemes={}
#       edata_schemes={'relation_type': Scheme(shape=(), dtype=torch.int64)})
# logits: tensor([[ 0.0351, -0.0410,  0.0106,  ...,  0.0439, -0.0003, -0.0595],
#         [ 0.0351, -0.0410,  0.0106,  ...,  0.0439, -0.0003, -0.0595],
#         [ 0.0351, -0.0410,  0.0106,  ...,  0.0439, -0.0003, -0.0595]],
#        grad_fn=<AddBackward0>)
# Raw scene_graph: [(' man ', ' v:have ', ' leg ')]
# relation: (' man ', ' v:have ', ' leg ')
# len(relation) 3
# Processed relation: src = man, rel = have, dst = leg
# nodes: ['man', 'leg']
# edges: [('man', 'have', 'leg')]
# node_to_id {'man': 0, 'leg': 1}
# relation_to_id: {'have': 0}
# src_nodes: [0]
# dst_nodes: [1]
# g (before adding self-loops): Graph(num_nodes=2, num_edges=1,
#       ndata_schemes={}
#       edata_schemes={})
# g (after adding self-loops): Graph(num_nodes=2, num_edges=3,
#       ndata_schemes={}
#       edata_schemes={})
# g with edge data: Graph(num_nodes=2, num_edges=3,
#       ndata_schemes={}
#       edata_schemes={'relation_type': Scheme(shape=(), dtype=torch.int64)})
# logits: tensor([[ 0.0332, -0.0415,  0.0112,  ...,  0.0419, -0.0012, -0.0579],
#         [ 0.0332, -0.0415,  0.0112,  ...,  0.0419, -0.0012, -0.0579]],
#        grad_fn=<AddBackward0>)
# Raw scene_graph: [(' oil ', ' v:cover ', ' road ')]
# relation: (' oil ', ' v:cover ', ' road ')
# len(relation) 3
# Processed relation: src = oil, rel = cover, dst = road
# nodes: ['oil', 'road']
# edges: [('oil', 'cover', 'road')]
# node_to_id {'oil': 0, 'road': 1}
# relation_to_id: {'cover': 0}
# src_nodes: [0]
# dst_nodes: [1]
# g (before adding self-loops): Graph(num_nodes=2, num_edges=1,
#       ndata_schemes={}
#       edata_schemes={})
# g (after adding self-loops): Graph(num_nodes=2, num_edges=3,
#       ndata_schemes={}
#       edata_schemes={})
# g with edge data: Graph(num_nodes=2, num_edges=3,
#       ndata_schemes={}
#       edata_schemes={'relation_type': Scheme(shape=(), dtype=torch.int64)})
# logits: tensor([[ 0.0314, -0.0400,  0.0112,  ...,  0.0402, -0.0024, -0.0541],
#         [ 0.0314, -0.0400,  0.0112,  ...,  0.0402, -0.0024, -0.0541]],
#        grad_fn=<AddBackward0>)
# Raw scene_graph: [(' pen ', ' v:enclose ', ' giraffes ')]
# relation: (' pen ', ' v:enclose ', ' giraffes ')
# len(relation) 3
# Processed relation: src = pen, rel = enclose, dst = giraffes
# nodes: ['giraffes', 'pen']
# edges: [('pen', 'enclose', 'giraffes')]
# node_to_id {'giraffes': 0, 'pen': 1}
# relation_to_id: {'enclose': 0}
# src_nodes: [1]
# dst_nodes: [0]
# g (before adding self-loops): Graph(num_nodes=2, num_edges=1,
#       ndata_schemes={}
#       edata_schemes={})
# g (after adding self-loops): Graph(num_nodes=2, num_edges=3,
#       ndata_schemes={}
#       edata_schemes={})
# g with edge data: Graph(num_nodes=2, num_edges=3,
#       ndata_schemes={}
#       edata_schemes={'relation_type': Scheme(shape=(), dtype=torch.int64)})
# logits: tensor([[ 0.0307, -0.0391,  0.0103,  ...,  0.0369, -0.0035, -0.0501],
#         [ 0.0307, -0.0391,  0.0103,  ...,  0.0369, -0.0035, -0.0501]],
#        grad_fn=<AddBackward0>)
# Raw scene_graph: [(' building ', ' behind ', ' street ) ', ' ( building ', ' is ', ' large ')]
# relation: (' building ', ' behind ', ' street ) ', ' ( building ', ' is ', ' large ')
# len(relation) 6
# Processed relation: src = building, rel = behind, dst = street
# Processed relation: src = building, rel = is, dst = large
# nodes: ['large', 'building', 'street']
# edges: [('building', 'behind', 'street'), ('building', 'is', 'large')]
# node_to_id {'large': 0, 'building': 1, 'street': 2}
# relation_to_id: {'behind': 0, 'is': 1}
# src_nodes: [1, 1]
# dst_nodes: [2, 0]
# g (before adding self-loops): Graph(num_nodes=3, num_edges=2,
#       ndata_schemes={}
#       edata_schemes={})
# g (after adding self-loops): Graph(num_nodes=3, num_edges=5,
#       ndata_schemes={}
#       edata_schemes={})
# g with edge data: Graph(num_nodes=3, num_edges=5,
#       ndata_schemes={}
#       edata_schemes={'relation_type': Scheme(shape=(), dtype=torch.int64)})
# logits: tensor([[ 0.0304, -0.0387,  0.0099,  ...,  0.0342, -0.0043, -0.0463],
#         [ 0.0304, -0.0387,  0.0099,  ...,  0.0342, -0.0043, -0.0463],
#         [ 0.0304, -0.0387,  0.0099,  ...,  0.0342, -0.0043, -0.0463]],
#        grad_fn=<AddBackward0>)
# Raw scene_graph: [(' towel ', ' is ', ' white ) ', ' ( man ', ' with ', ' towel ) ', ' ( man ', ' v:sit on ', ' sidelines ')]
# relation: (' towel ', ' is ', ' white ) ', ' ( man ', ' with ', ' towel ) ', ' ( man ', ' v:sit on ', ' sidelines ')
# len(relation) 9
# Processed relation: src = towel, rel = is, dst = white
# Processed relation: src = man, rel = with, dst = towel
# Processed relation: src = man, rel = sit on, dst = sidelines
# nodes: ['white', 'sidelines', 'man', 'towel']
# edges: [('towel', 'is', 'white'), ('man', 'with', 'towel'), ('man', 'sit on', 'sidelines')]
# node_to_id {'white': 0, 'sidelines': 1, 'man': 2, 'towel': 3}
# relation_to_id: {'is': 0, 'with': 1, 'sit on': 2}
# src_nodes: [3, 2, 2]
# dst_nodes: [0, 3, 1]
# g (before adding self-loops): Graph(num_nodes=4, num_edges=3,
#       ndata_schemes={}
#       edata_schemes={})
# g (after adding self-loops): Graph(num_nodes=4, num_edges=7,
#       ndata_schemes={}
#       edata_schemes={})
# g with edge data: Graph(num_nodes=4, num_edges=7,
#       ndata_schemes={}
#       edata_schemes={'relation_type': Scheme(shape=(), dtype=torch.int64)})
# logits: tensor([[ 0.0296, -0.0371,  0.0108,  ...,  0.0315, -0.0053, -0.0422],
#         [ 0.0296, -0.0371,  0.0108,  ...,  0.0315, -0.0053, -0.0422],
#         [ 0.0296, -0.0371,  0.0108,  ...,  0.0315, -0.0053, -0.0422],
#         [ 0.0296, -0.0371,  0.0108,  ...,  0.0315, -0.0053, -0.0422]],
#        grad_fn=<AddBackward0>)
# Raw scene_graph: [(' plants ', ' is ', ' 2 ')]
# relation: (' plants ', ' is ', ' 2 ')
# len(relation) 3
# Processed relation: src = plants, rel = is, dst = 2
# nodes: ['2', 'plants']
# edges: [('plants', 'is', '2')]
# node_to_id {'2': 0, 'plants': 1}
# relation_to_id: {'is': 0}
# src_nodes: [1]
# dst_nodes: [0]
# g (before adding self-loops): Graph(num_nodes=2, num_edges=1,
#       ndata_schemes={}
#       edata_schemes={})
# g (after adding self-loops): Graph(num_nodes=2, num_edges=3,
#       ndata_schemes={}
#       edata_schemes={})
# g with edge data: Graph(num_nodes=2, num_edges=3,
#       ndata_schemes={}
#       edata_schemes={'relation_type': Scheme(shape=(), dtype=torch.int64)})
# logits: tensor([[ 0.0287, -0.0363,  0.0126,  ...,  0.0284, -0.0058, -0.0376],
#         [ 0.0287, -0.0363,  0.0126,  ...,  0.0284, -0.0058, -0.0376]],
#        grad_fn=<AddBackward0>)
# Raw scene_graph: [(' desk ', ' is ', ' wooden ) ', ' ( desk ', ' in ', ' office ')]
# relation: (' desk ', ' is ', ' wooden ) ', ' ( desk ', ' in ', ' office ')
# len(relation) 6
# Processed relation: src = desk, rel = is, dst = wooden
# Processed relation: src = desk, rel = in, dst = office
# nodes: ['wooden', 'desk', 'office']
# edges: [('desk', 'is', 'wooden'), ('desk', 'in', 'office')]
# node_to_id {'wooden': 0, 'desk': 1, 'office': 2}
# relation_to_id: {'is': 0, 'in': 1}
# src_nodes: [1, 1]
# dst_nodes: [0, 2]
# g (before adding self-loops): Graph(num_nodes=3, num_edges=2,
#       ndata_schemes={}
#       edata_schemes={})
# g (after adding self-loops): Graph(num_nodes=3, num_edges=5,
#       ndata_schemes={}
#       edata_schemes={})
# g with edge data: Graph(num_nodes=3, num_edges=5,
#       ndata_schemes={}
#       edata_schemes={'relation_type': Scheme(shape=(), dtype=torch.int64)})
# logits: tensor([[ 0.0272, -0.0335,  0.0154,  ...,  0.0259, -0.0085, -0.0339],
#         [ 0.0272, -0.0335,  0.0154,  ...,  0.0259, -0.0085, -0.0339],
#         [ 0.0272, -0.0335,  0.0154,  ...,  0.0259, -0.0085, -0.0339]],
#        grad_fn=<AddBackward0>)
# Raw scene_graph: [(' mirror ', ' v:lean against ', ' wall ')]
# relation: (' mirror ', ' v:lean against ', ' wall ')
# len(relation) 3
# Processed relation: src = mirror, rel = lean against, dst = wall
# nodes: ['wall', 'mirror']
# edges: [('mirror', 'lean against', 'wall')]
# node_to_id {'wall': 0, 'mirror': 1}
# relation_to_id: {'lean against': 0}
# src_nodes: [1]
# dst_nodes: [0]
# g (before adding self-loops): Graph(num_nodes=2, num_edges=1,
#       ndata_schemes={}
#       edata_schemes={})
# g (after adding self-loops): Graph(num_nodes=2, num_edges=3,
#       ndata_schemes={}
#       edata_schemes={})
# g with edge data: Graph(num_nodes=2, num_edges=3,
#       ndata_schemes={}
#       edata_schemes={'relation_type': Scheme(shape=(), dtype=torch.int64)})
# logits: tensor([[ 0.0244, -0.0312,  0.0171,  ...,  0.0239, -0.0110, -0.0305],
#         [ 0.0244, -0.0312,  0.0171,  ...,  0.0239, -0.0110, -0.0305]],
#        grad_fn=<AddBackward0>)
# Raw scene_graph: [(' bench ', ' is ', ' wooden ) ', ' ( bench ', ' v:face ', ' sea ')]
# relation: (' bench ', ' is ', ' wooden ) ', ' ( bench ', ' v:face ', ' sea ')
# len(relation) 6
# Processed relation: src = bench, rel = is, dst = wooden
# Processed relation: src = bench, rel = face, dst = sea
# nodes: ['wooden', 'bench', 'sea']
# edges: [('bench', 'is', 'wooden'), ('bench', 'face', 'sea')]
# node_to_id {'wooden': 0, 'bench': 1, 'sea': 2}
# relation_to_id: {'is': 0, 'face': 1}
# src_nodes: [1, 1]
# dst_nodes: [0, 2]
# g (before adding self-loops): Graph(num_nodes=3, num_edges=2,
#       ndata_schemes={}
#       edata_schemes={})
# g (after adding self-loops): Graph(num_nodes=3, num_edges=5,
#       ndata_schemes={}
#       edata_schemes={})
# g with edge data: Graph(num_nodes=3, num_edges=5,
#       ndata_schemes={}
#       edata_schemes={'relation_type': Scheme(shape=(), dtype=torch.int64)})
# logits: tensor([[ 0.0218, -0.0286,  0.0206,  ...,  0.0231, -0.0117, -0.0261],
#         [ 0.0218, -0.0286,  0.0206,  ...,  0.0231, -0.0117, -0.0261],
#         [ 0.0218, -0.0286,  0.0206,  ...,  0.0231, -0.0117, -0.0261]],
#        grad_fn=<AddBackward0>)
# Raw scene_graph: [(' man ', ' v:have ', ' ear ')]
# relation: (' man ', ' v:have ', ' ear ')
# len(relation) 3
# Processed relation: src = man, rel = have, dst = ear
# nodes: ['ear', 'man']
# edges: [('man', 'have', 'ear')]
# node_to_id {'ear': 0, 'man': 1}
# relation_to_id: {'have': 0}
# src_nodes: [1]
# dst_nodes: [0]
# g (before adding self-loops): Graph(num_nodes=2, num_edges=1,
#       ndata_schemes={}
#       edata_schemes={})
# g (after adding self-loops): Graph(num_nodes=2, num_edges=3,
#       ndata_schemes={}
#       edata_schemes={})
# g with edge data: Graph(num_nodes=2, num_edges=3,
#       ndata_schemes={}
#       edata_schemes={'relation_type': Scheme(shape=(), dtype=torch.int64)})
# logits: tensor([[ 0.0210, -0.0275,  0.0213,  ...,  0.0220, -0.0131, -0.0216],
#         [ 0.0210, -0.0275,  0.0213,  ...,  0.0220, -0.0131, -0.0216]],
#        grad_fn=<AddBackward0>)
# Raw scene_graph: [(' pole ', ' is ', ' green ) ', ' ( pole ', ' pv:bury in ', ' dirt ')]
# relation: (' pole ', ' is ', ' green ) ', ' ( pole ', ' pv:bury in ', ' dirt ')
# len(relation) 6
# Processed relation: src = pole, rel = is, dst = green
# Processed relation: src = pole, rel = pv:bury in, dst = dirt
# nodes: ['dirt', 'pole', 'green']
# edges: [('pole', 'is', 'green'), ('pole', 'pv:bury in', 'dirt')]
# node_to_id {'dirt': 0, 'pole': 1, 'green': 2}
# relation_to_id: {'is': 0, 'pv:bury in': 1}
# src_nodes: [1, 1]
# dst_nodes: [2, 0]
# g (before adding self-loops): Graph(num_nodes=3, num_edges=2,
#       ndata_schemes={}
#       edata_schemes={})
# g (after adding self-loops): Graph(num_nodes=3, num_edges=5,
#       ndata_schemes={}
#       edata_schemes={})
# g with edge data: Graph(num_nodes=3, num_edges=5,
#       ndata_schemes={}
#       edata_schemes={'relation_type': Scheme(shape=(), dtype=torch.int64)})
# logits: tensor([[ 0.0205, -0.0262,  0.0204,  ...,  0.0222, -0.0148, -0.0195],
#         [ 0.0205, -0.0262,  0.0204,  ...,  0.0222, -0.0148, -0.0195],
#         [ 0.0205, -0.0262,  0.0204,  ...,  0.0222, -0.0148, -0.0195]],
#        grad_fn=<AddBackward0>)
# Raw scene_graph: [(' grass ', ' is ', ' green ) ', ' ( grass ', ' v:line ', ' tarmac ')]
# relation: (' grass ', ' is ', ' green ) ', ' ( grass ', ' v:line ', ' tarmac ')
# len(relation) 6
# Processed relation: src = grass, rel = is, dst = green
# Processed relation: src = grass, rel = line, dst = tarmac
# nodes: ['tarmac', 'grass', 'green']
# edges: [('grass', 'is', 'green'), ('grass', 'line', 'tarmac')]
# node_to_id {'tarmac': 0, 'grass': 1, 'green': 2}
# relation_to_id: {'is': 0, 'line': 1}
# src_nodes: [1, 1]
# dst_nodes: [2, 0]
# g (before adding self-loops): Graph(num_nodes=3, num_edges=2,
#       ndata_schemes={}
#       edata_schemes={})
# g (after adding self-loops): Graph(num_nodes=3, num_edges=5,
#       ndata_schemes={}
#       edata_schemes={})
# g with edge data: Graph(num_nodes=3, num_edges=5,
#       ndata_schemes={}
#       edata_schemes={'relation_type': Scheme(shape=(), dtype=torch.int64)})
# logits: tensor([[ 0.0211, -0.0241,  0.0198,  ...,  0.0237, -0.0167, -0.0171],
#         [ 0.0211, -0.0241,  0.0198,  ...,  0.0237, -0.0167, -0.0171],
#         [ 0.0211, -0.0241,  0.0198,  ...,  0.0237, -0.0167, -0.0171]],
#        grad_fn=<AddBackward0>)
# Raw scene_graph: [(' water ', ' v:surround ', ' fence ')]
# relation: (' water ', ' v:surround ', ' fence ')
# len(relation) 3
# Processed relation: src = water, rel = surround, dst = fence
# nodes: ['fence', 'water']
# edges: [('water', 'surround', 'fence')]
# node_to_id {'fence': 0, 'water': 1}
# relation_to_id: {'surround': 0}
# src_nodes: [1]
# dst_nodes: [0]
# g (before adding self-loops): Graph(num_nodes=2, num_edges=1,
#       ndata_schemes={}
#       edata_schemes={})
# g (after adding self-loops): Graph(num_nodes=2, num_edges=3,
#       ndata_schemes={}
#       edata_schemes={})
# g with edge data: Graph(num_nodes=2, num_edges=3,
#       ndata_schemes={}
#       edata_schemes={'relation_type': Scheme(shape=(), dtype=torch.int64)})
# logits: tensor([[ 0.0215, -0.0219,  0.0197,  ...,  0.0234, -0.0181, -0.0161],
#         [ 0.0215, -0.0219,  0.0197,  ...,  0.0234, -0.0181, -0.0161]],
#        grad_fn=<AddBackward0>)
# Raw scene_graph: [(' fire hydrant ', ' next to ', ' sidewalk ')]
# relation: (' fire hydrant ', ' next to ', ' sidewalk ')
# len(relation) 3
# Processed relation: src = fire hydrant, rel = next to, dst = sidewalk
# nodes: ['fire hydrant', 'sidewalk']
# edges: [('fire hydrant', 'next to', 'sidewalk')]
# node_to_id {'fire hydrant': 0, 'sidewalk': 1}
# relation_to_id: {'next to': 0}
# src_nodes: [0]
# dst_nodes: [1]
# g (before adding self-loops): Graph(num_nodes=2, num_edges=1,
#       ndata_schemes={}
#       edata_schemes={})
# g (after adding self-loops): Graph(num_nodes=2, num_edges=3,
#       ndata_schemes={}
#       edata_schemes={})
# g with edge data: Graph(num_nodes=2, num_edges=3,
#       ndata_schemes={}
#       edata_schemes={'relation_type': Scheme(shape=(), dtype=torch.int64)})
# logits: tensor([[ 0.0223, -0.0213,  0.0186,  ...,  0.0245, -0.0196, -0.0154],
#         [ 0.0223, -0.0213,  0.0186,  ...,  0.0245, -0.0196, -0.0154]],
#        grad_fn=<AddBackward0>)
# Raw scene_graph: [(' man ', ' v:have ', ' head ) ', ' ( hair ', ' is ', ' brown ) ', ' ( hair ', ' on ', ' head ')]
# relation: (' man ', ' v:have ', ' head ) ', ' ( hair ', ' is ', ' brown ) ', ' ( hair ', ' on ', ' head ')
# len(relation) 9
# Processed relation: src = man, rel = have, dst = head
# Processed relation: src = hair, rel = is, dst = brown
# Processed relation: src = hair, rel = on, dst = head
# nodes: ['hair', 'brown', 'man', 'head']
# edges: [('man', 'have', 'head'), ('hair', 'is', 'brown'), ('hair', 'on', 'head')]
# node_to_id {'hair': 0, 'brown': 1, 'man': 2, 'head': 3}
# relation_to_id: {'have': 0, 'is': 1, 'on': 2}
# src_nodes: [2, 0, 0]
# dst_nodes: [3, 1, 3]
# g (before adding self-loops): Graph(num_nodes=4, num_edges=3,
#       ndata_schemes={}
#       edata_schemes={})
# g (after adding self-loops): Graph(num_nodes=4, num_edges=7,
#       ndata_schemes={}
#       edata_schemes={})
# g with edge data: Graph(num_nodes=4, num_edges=7,
#       ndata_schemes={}
#       edata_schemes={'relation_type': Scheme(shape=(), dtype=torch.int64)})
# logits: tensor([[ 0.0213, -0.0212,  0.0151,  ...,  0.0253, -0.0216, -0.0138],
#         [ 0.0213, -0.0212,  0.0151,  ...,  0.0253, -0.0216, -0.0138],
#         [ 0.0213, -0.0212,  0.0151,  ...,  0.0253, -0.0216, -0.0138],
#         [ 0.0213, -0.0212,  0.0151,  ...,  0.0253, -0.0216, -0.0138]],
#        grad_fn=<AddBackward0>)
# Raw scene_graph: [(' log ', ' v:lean against ', ' fence ) ', ' ( fence ', ' is ', ' wooden ')]
# relation: (' log ', ' v:lean against ', ' fence ) ', ' ( fence ', ' is ', ' wooden ')
# len(relation) 6
# Processed relation: src = log, rel = lean against, dst = fence
# Processed relation: src = fence, rel = is, dst = wooden
# nodes: ['wooden', 'log', 'fence']
# edges: [('log', 'lean against', 'fence'), ('fence', 'is', 'wooden')]
# node_to_id {'wooden': 0, 'log': 1, 'fence': 2}
# relation_to_id: {'lean against': 0, 'is': 1}
# src_nodes: [1, 2]
# dst_nodes: [2, 0]
# g (before adding self-loops): Graph(num_nodes=3, num_edges=2,
#       ndata_schemes={}
#       edata_schemes={})
# g (after adding self-loops): Graph(num_nodes=3, num_edges=5,
#       ndata_schemes={}
#       edata_schemes={})
# g with edge data: Graph(num_nodes=3, num_edges=5,
#       ndata_schemes={}
#       edata_schemes={'relation_type': Scheme(shape=(), dtype=torch.int64)})
# logits: tensor([[ 0.0209, -0.0228,  0.0123,  ...,  0.0270, -0.0229, -0.0115],
#         [ 0.0209, -0.0228,  0.0123,  ...,  0.0270, -0.0229, -0.0115],
#         [ 0.0209, -0.0228,  0.0123,  ...,  0.0270, -0.0229, -0.0115]],
#        grad_fn=<AddBackward0>)
# Raw scene_graph: [(' sky ', ' v:have ', ' clouds ')]
# relation: (' sky ', ' v:have ', ' clouds ')
# len(relation) 3
# Processed relation: src = sky, rel = have, dst = clouds
# nodes: ['clouds', 'sky']
# edges: [('sky', 'have', 'clouds')]
# node_to_id {'clouds': 0, 'sky': 1}
# relation_to_id: {'have': 0}
# src_nodes: [1]
# dst_nodes: [0]
# g (before adding self-loops): Graph(num_nodes=2, num_edges=1,
#       ndata_schemes={}
#       edata_schemes={})
# g (after adding self-loops): Graph(num_nodes=2, num_edges=3,
#       ndata_schemes={}
#       edata_schemes={})
# g with edge data: Graph(num_nodes=2, num_edges=3,
#       ndata_schemes={}
#       edata_schemes={'relation_type': Scheme(shape=(), dtype=torch.int64)})
# logits: tensor([[ 0.0192, -0.0251,  0.0081,  ...,  0.0278, -0.0257, -0.0106],
#         [ 0.0192, -0.0251,  0.0081,  ...,  0.0278, -0.0257, -0.0106]],
#        grad_fn=<AddBackward0>)
# Raw scene_graph: [(' string ', ' pv:attach to ', ' kite ')]
# relation: (' string ', ' pv:attach to ', ' kite ')
# len(relation) 3
# Processed relation: src = string, rel = pv:attach to, dst = kite
# nodes: ['string', 'kite']
# edges: [('string', 'pv:attach to', 'kite')]
# node_to_id {'string': 0, 'kite': 1}
# relation_to_id: {'pv:attach to': 0}
# src_nodes: [0]
# dst_nodes: [1]
# g (before adding self-loops): Graph(num_nodes=2, num_edges=1,
#       ndata_schemes={}
#       edata_schemes={})
# g (after adding self-loops): Graph(num_nodes=2, num_edges=3,
#       ndata_schemes={}
#       edata_schemes={})
# g with edge data: Graph(num_nodes=2, num_edges=3,
#       ndata_schemes={}
#       edata_schemes={'relation_type': Scheme(shape=(), dtype=torch.int64)})
# logits: tensor([[ 0.0176, -0.0267,  0.0028,  ...,  0.0298, -0.0283, -0.0119],
#         [ 0.0176, -0.0267,  0.0028,  ...,  0.0298, -0.0283, -0.0119]],
#        grad_fn=<AddBackward0>)
# Raw scene_graph: [(' boys ', ' is ', ' 2 ) ', ' ( boys ', ' v:ride ', ' skateboards ) ', ' ( skateboards ', ' is ', ' 2 ')]
# relation: (' boys ', ' is ', ' 2 ) ', ' ( boys ', ' v:ride ', ' skateboards ) ', ' ( skateboards ', ' is ', ' 2 ')
# len(relation) 9
# Processed relation: src = boys, rel = is, dst = 2
# Processed relation: src = boys, rel = ride, dst = skateboards
# Processed relation: src = skateboards, rel = is, dst = 2
# nodes: ['boys', '2', 'skateboards']
# edges: [('boys', 'is', '2'), ('boys', 'ride', 'skateboards'), ('skateboards', 'is', '2')]
# node_to_id {'boys': 0, '2': 1, 'skateboards': 2}
# relation_to_id: {'is': 2, 'ride': 1}
# src_nodes: [0, 0, 2]
# dst_nodes: [1, 2, 1]
# g (before adding self-loops): Graph(num_nodes=3, num_edges=3,
#       ndata_schemes={}
#       edata_schemes={})
# g (after adding self-loops): Graph(num_nodes=3, num_edges=6,
#       ndata_schemes={}
#       edata_schemes={})
# g with edge data: Graph(num_nodes=3, num_edges=6,
#       ndata_schemes={}
#       edata_schemes={'relation_type': Scheme(shape=(), dtype=torch.int64)})
# logits: tensor([[ 0.0148, -0.0292, -0.0028,  ...,  0.0310, -0.0315, -0.0136],
#         [ 0.0148, -0.0292, -0.0028,  ...,  0.0310, -0.0315, -0.0136],
#         [ 0.0148, -0.0292, -0.0028,  ...,  0.0310, -0.0315, -0.0136]],
#        grad_fn=<AddBackward0>)
# Raw scene_graph: [(' boy ', ' v:look out ', ' window ')]
# relation: (' boy ', ' v:look out ', ' window ')
# len(relation) 3
# Processed relation: src = boy, rel = look out, dst = window
# nodes: ['boy', 'window']
# edges: [('boy', 'look out', 'window')]
# node_to_id {'boy': 0, 'window': 1}
# relation_to_id: {'look out': 0}
# src_nodes: [0]
# dst_nodes: [1]
# g (before adding self-loops): Graph(num_nodes=2, num_edges=1,
#       ndata_schemes={}
#       edata_schemes={})
# g (after adding self-loops): Graph(num_nodes=2, num_edges=3,
#       ndata_schemes={}
#       edata_schemes={})
# g with edge data: Graph(num_nodes=2, num_edges=3,
#       ndata_schemes={}
#       edata_schemes={'relation_type': Scheme(shape=(), dtype=torch.int64)})
# logits: tensor([[ 0.0140, -0.0311, -0.0078,  ...,  0.0309, -0.0335, -0.0137],
#         [ 0.0140, -0.0311, -0.0078,  ...,  0.0309, -0.0335, -0.0137]],
#        grad_fn=<AddBackward0>)
# Raw scene_graph: [(' man ', ' v:sit on ', ' sofa ')]
# relation: (' man ', ' v:sit on ', ' sofa ')
# len(relation) 3
# Processed relation: src = man, rel = sit on, dst = sofa
# nodes: ['sofa', 'man']
# edges: [('man', 'sit on', 'sofa')]
# node_to_id {'sofa': 0, 'man': 1}
# relation_to_id: {'sit on': 0}
# src_nodes: [1]
# dst_nodes: [0]
# g (before adding self-loops): Graph(num_nodes=2, num_edges=1,
#       ndata_schemes={}
#       edata_schemes={})
# g (after adding self-loops): Graph(num_nodes=2, num_edges=3,
#       ndata_schemes={}
#       edata_schemes={})
# g with edge data: Graph(num_nodes=2, num_edges=3,
#       ndata_schemes={}
#       edata_schemes={'relation_type': Scheme(shape=(), dtype=torch.int64)})
# logits: tensor([[ 0.0132, -0.0309, -0.0128,  ...,  0.0324, -0.0339, -0.0132],
#         [ 0.0132, -0.0309, -0.0128,  ...,  0.0324, -0.0339, -0.0132]],
#        grad_fn=<AddBackward0>)
# Raw scene_graph: [(' shower door ', ' is ', ' opening ) ', ' ( towel ', ' on face of ', ' shower door ')]
# relation: (' shower door ', ' is ', ' opening ) ', ' ( towel ', ' on face of ', ' shower door ')
# len(relation) 6
# Processed relation: src = shower door, rel = is, dst = opening
# Processed relation: src = towel, rel = on face of, dst = shower door
# nodes: ['opening', 'shower door', 'towel']
# edges: [('shower door', 'is', 'opening'), ('towel', 'on face of', 'shower door')]
# node_to_id {'opening': 0, 'shower door': 1, 'towel': 2}
# relation_to_id: {'is': 0, 'on face of': 1}
# src_nodes: [1, 2]
# dst_nodes: [0, 1]
# g (before adding self-loops): Graph(num_nodes=3, num_edges=2,
#       ndata_schemes={}
#       edata_schemes={})
# g (after adding self-loops): Graph(num_nodes=3, num_edges=5,
#       ndata_schemes={}
#       edata_schemes={})
# g with edge data: Graph(num_nodes=3, num_edges=5,
#       ndata_schemes={}
#       edata_schemes={'relation_type': Scheme(shape=(), dtype=torch.int64)})
# logits: tensor([[ 0.0107, -0.0321, -0.0170,  ...,  0.0323, -0.0346, -0.0126],
#         [ 0.0107, -0.0321, -0.0170,  ...,  0.0323, -0.0346, -0.0126],
#         [ 0.0107, -0.0321, -0.0170,  ...,  0.0323, -0.0346, -0.0126]],
#        grad_fn=<AddBackward0>)
# Raw scene_graph: [(' t-shirt ', ' is ', ' red ')]
# relation: (' t-shirt ', ' is ', ' red ')
# len(relation) 3
# Processed relation: src = t-shirt, rel = is, dst = red
# nodes: ['red', 't-shirt']
# edges: [('t-shirt', 'is', 'red')]
# node_to_id {'red': 0, 't-shirt': 1}
# relation_to_id: {'is': 0}
# src_nodes: [1]
# dst_nodes: [0]
# g (before adding self-loops): Graph(num_nodes=2, num_edges=1,
#       ndata_schemes={}
#       edata_schemes={})
# g (after adding self-loops): Graph(num_nodes=2, num_edges=3,
#       ndata_schemes={}
#       edata_schemes={})
# g with edge data: Graph(num_nodes=2, num_edges=3,
#       ndata_schemes={}
#       edata_schemes={'relation_type': Scheme(shape=(), dtype=torch.int64)})
# logits: tensor([[ 0.0104, -0.0313, -0.0217,  ...,  0.0318, -0.0355, -0.0119],
#         [ 0.0104, -0.0313, -0.0217,  ...,  0.0318, -0.0355, -0.0119]],
#        grad_fn=<AddBackward0>)
# Raw scene_graph: [(' horse ', ' v:walk on ', ' sidewalk ')]
# relation: (' horse ', ' v:walk on ', ' sidewalk ')
# len(relation) 3
# Processed relation: src = horse, rel = walk on, dst = sidewalk
# nodes: ['sidewalk', 'horse']
# edges: [('horse', 'walk on', 'sidewalk')]
# node_to_id {'sidewalk': 0, 'horse': 1}
# relation_to_id: {'walk on': 0}
# src_nodes: [1]
# dst_nodes: [0]
# g (before adding self-loops): Graph(num_nodes=2, num_edges=1,
#       ndata_schemes={}
#       edata_schemes={})
# g (after adding self-loops): Graph(num_nodes=2, num_edges=3,
#       ndata_schemes={}
#       edata_schemes={})
# g with edge data: Graph(num_nodes=2, num_edges=3,
#       ndata_schemes={}
#       edata_schemes={'relation_type': Scheme(shape=(), dtype=torch.int64)})
# logits: tensor([[ 0.0120, -0.0310, -0.0282,  ...,  0.0311, -0.0378, -0.0114],
#         [ 0.0120, -0.0310, -0.0282,  ...,  0.0311, -0.0378, -0.0114]],
#        grad_fn=<AddBackward0>)
# Raw scene_graph: [(' graffiti ', ' on ', ' sign ')]
# relation: (' graffiti ', ' on ', ' sign ')
# len(relation) 3
# Processed relation: src = graffiti, rel = on, dst = sign
# nodes: ['sign', 'graffiti']
# edges: [('graffiti', 'on', 'sign')]
# node_to_id {'sign': 0, 'graffiti': 1}
# relation_to_id: {'on': 0}
# src_nodes: [1]
# dst_nodes: [0]
# g (before adding self-loops): Graph(num_nodes=2, num_edges=1,
#       ndata_schemes={}
#       edata_schemes={})
# g (after adding self-loops): Graph(num_nodes=2, num_edges=3,
#       ndata_schemes={}
#       edata_schemes={})
# g with edge data: Graph(num_nodes=2, num_edges=3,
#       ndata_schemes={}
#       edata_schemes={'relation_type': Scheme(shape=(), dtype=torch.int64)})
# logits: tensor([[ 0.0135, -0.0300, -0.0333,  ...,  0.0283, -0.0417, -0.0122],
#         [ 0.0135, -0.0300, -0.0333,  ...,  0.0283, -0.0417, -0.0122]],
#        grad_fn=<AddBackward0>)
# Raw scene_graph: [(' giraffe ', ' v:walk in ', ' field ')]
# relation: (' giraffe ', ' v:walk in ', ' field ')
# len(relation) 3
# Processed relation: src = giraffe, rel = walk in, dst = field
# nodes: ['giraffe', 'field']
# edges: [('giraffe', 'walk in', 'field')]
# node_to_id {'giraffe': 0, 'field': 1}
# relation_to_id: {'walk in': 0}
# src_nodes: [0]
# dst_nodes: [1]
# g (before adding self-loops): Graph(num_nodes=2, num_edges=1,
#       ndata_schemes={}
#       edata_schemes={})
# g (after adding self-loops): Graph(num_nodes=2, num_edges=3,
#       ndata_schemes={}
#       edata_schemes={})
# g with edge data: Graph(num_nodes=2, num_edges=3,
#       ndata_schemes={}
#       edata_schemes={'relation_type': Scheme(shape=(), dtype=torch.int64)})
# logits: tensor([[ 0.0149, -0.0267, -0.0393,  ...,  0.0240, -0.0432, -0.0129],
#         [ 0.0149, -0.0267, -0.0393,  ...,  0.0240, -0.0432, -0.0129]],
#        grad_fn=<AddBackward0>)
# Raw scene_graph: [(' platter ', ' is ', ' black ) ', ' ( platter ', ' under ', ' pizza ')]
# relation: (' platter ', ' is ', ' black ) ', ' ( platter ', ' under ', ' pizza ')
# len(relation) 6
# Processed relation: src = platter, rel = is, dst = black
# Processed relation: src = platter, rel = under, dst = pizza
# nodes: ['black', 'pizza', 'platter']
# edges: [('platter', 'is', 'black'), ('platter', 'under', 'pizza')]
# node_to_id {'black': 0, 'pizza': 1, 'platter': 2}
# relation_to_id: {'is': 0, 'under': 1}
# src_nodes: [2, 2]
# dst_nodes: [0, 1]
# g (before adding self-loops): Graph(num_nodes=3, num_edges=2,
#       ndata_schemes={}
#       edata_schemes={})
# g (after adding self-loops): Graph(num_nodes=3, num_edges=5,
#       ndata_schemes={}
#       edata_schemes={})
# g with edge data: Graph(num_nodes=3, num_edges=5,
#       ndata_schemes={}
#       edata_schemes={'relation_type': Scheme(shape=(), dtype=torch.int64)})
# logits: tensor([[ 0.0180, -0.0224, -0.0439,  ...,  0.0191, -0.0456, -0.0126],
#         [ 0.0180, -0.0224, -0.0439,  ...,  0.0191, -0.0456, -0.0126],
#         [ 0.0180, -0.0224, -0.0439,  ...,  0.0191, -0.0456, -0.0126]],
#        grad_fn=<AddBackward0>)
# Raw scene_graph: [(' curtains ', ' is ', ' dark ) ', ' ( curtains ', ' v:surround ', ' window ')]
# relation: (' curtains ', ' is ', ' dark ) ', ' ( curtains ', ' v:surround ', ' window ')
# ...
#       ndata_schemes={}
#       edata_schemes={})
# g with edge data: Graph(num_nodes=3, num_edges=5,
#       ndata_schemes={}
#       edata_schemes={'relation_type': Scheme(shape=(), dtype=torch.int64)})
# logits: tensor([[-0.0086,  0.0727, -0.0546,  ...,  0.0832, -0.0506,  0.0223],
#         [-0.0086,  0.0727, -0.0546,  ...,  0.0832, -0.0506,  0.0223],
#         [-0.0086,  0.0727, -0.0546,  ...,  0.0832, -0.0506,  0.0223]],
#        grad_fn=<AddBackward0>)
# Raw scene_graph: [(' motorcycle ', ' v:lean against ', ' wall ')]
# relation: (' motorcycle ', ' v:lean against ', ' wall ')
# len(relation) 3
# Processed relation: src = motorcycle, rel = lean against, dst = wall
# nodes: ['wall', 'motorcycle']
# edges: [('motorcycle', 'lean against', 'wall')]
# node_to_id {'wall': 0, 'motorcycle': 1}
# relation_to_id: {'lean against': 0}
# src_nodes: [1]
# dst_nodes: [0]
# g (before adding self-loops): Graph(num_nodes=2, num_edges=1,
#       ndata_schemes={}
#       edata_schemes={})
# g (after adding self-loops): Graph(num_nodes=2, num_edges=3,
#       ndata_schemes={}
#       edata_schemes={})
# g with edge data: Graph(num_nodes=2, num_edges=3,
#       ndata_schemes={}
#       edata_schemes={'relation_type': Scheme(shape=(), dtype=torch.int64)})
# logits: tensor([[-0.0092,  0.0698, -0.0561,  ...,  0.0818, -0.0516,  0.0227],
#         [-0.0092,  0.0698, -0.0561,  ...,  0.0818, -0.0516,  0.0227]],
#        grad_fn=<AddBackward0>)
# Raw scene_graph: [(' people ', ' on ', ' sand ')]
# relation: (' people ', ' on ', ' sand ')
# len(relation) 3
# Processed relation: src = people, rel = on, dst = sand
# nodes: ['people', 'sand']
# edges: [('people', 'on', 'sand')]
# node_to_id {'people': 0, 'sand': 1}
# relation_to_id: {'on': 0}
# src_nodes: [0]
# dst_nodes: [1]
# g (before adding self-loops): Graph(num_nodes=2, num_edges=1,
#       ndata_schemes={}
#       edata_schemes={})
# g (after adding self-loops): Graph(num_nodes=2, num_edges=3,
#       ndata_schemes={}
#       edata_schemes={})
# g with edge data: Graph(num_nodes=2, num_edges=3,
#       ndata_schemes={}
#       edata_schemes={'relation_type': Scheme(shape=(), dtype=torch.int64)})
# logits: tensor([[-0.0100,  0.0686, -0.0549,  ...,  0.0799, -0.0509,  0.0221],
#         [-0.0100,  0.0686, -0.0549,  ...,  0.0799, -0.0509,  0.0221]],
#        grad_fn=<AddBackward0>)
# Raw scene_graph: [(' wall ', ' in ', ' room ) ', ' ( wall ', ' is ', ' brownish ) ', ' ( wall ', ' is ', ' orange ')]
# relation: (' wall ', ' in ', ' room ) ', ' ( wall ', ' is ', ' brownish ) ', ' ( wall ', ' is ', ' orange ')
# len(relation) 9
# Processed relation: src = wall, rel = in, dst = room
# Processed relation: src = wall, rel = is, dst = brownish
# Processed relation: src = wall, rel = is, dst = orange
# nodes: ['wall', 'orange', 'brownish', 'room']
# edges: [('wall', 'in', 'room'), ('wall', 'is', 'brownish'), ('wall', 'is', 'orange')]
# node_to_id {'wall': 0, 'orange': 1, 'brownish': 2, 'room': 3}
# relation_to_id: {'in': 0, 'is': 2}
# src_nodes: [0, 0, 0]
# dst_nodes: [3, 2, 1]
# g (before adding self-loops): Graph(num_nodes=4, num_edges=3,
#       ndata_schemes={}
#       edata_schemes={})
# g (after adding self-loops): Graph(num_nodes=4, num_edges=7,
#       ndata_schemes={}
#       edata_schemes={})
# g with edge data: Graph(num_nodes=4, num_edges=7,
#       ndata_schemes={}
#       edata_schemes={'relation_type': Scheme(shape=(), dtype=torch.int64)})
# logits: tensor([[-0.0103,  0.0694, -0.0528,  ...,  0.0802, -0.0506,  0.0225],
#         [-0.0103,  0.0694, -0.0528,  ...,  0.0802, -0.0506,  0.0225],
#         [-0.0103,  0.0694, -0.0528,  ...,  0.0802, -0.0506,  0.0225],
#         [-0.0103,  0.0694, -0.0528,  ...,  0.0802, -0.0506,  0.0225]],
#        grad_fn=<AddBackward0>)
# Raw scene_graph: [(' mirror ', ' v:hang above ', ' sink ')]
# relation: (' mirror ', ' v:hang above ', ' sink ')
# len(relation) 3
# Processed relation: src = mirror, rel = hang above, dst = sink
# nodes: ['sink', 'mirror']
# edges: [('mirror', 'hang above', 'sink')]
# node_to_id {'sink': 0, 'mirror': 1}
# relation_to_id: {'hang above': 0}
# src_nodes: [1]
# dst_nodes: [0]
# g (before adding self-loops): Graph(num_nodes=2, num_edges=1,
#       ndata_schemes={}
#       edata_schemes={})
# g (after adding self-loops): Graph(num_nodes=2, num_edges=3,
#       ndata_schemes={}
#       edata_schemes={})
# g with edge data: Graph(num_nodes=2, num_edges=3,
#       ndata_schemes={}
#       edata_schemes={'relation_type': Scheme(shape=(), dtype=torch.int64)})
# logits: tensor([[-0.0105,  0.0704, -0.0495,  ...,  0.0791, -0.0496,  0.0236],
#         [-0.0105,  0.0704, -0.0495,  ...,  0.0791, -0.0496,  0.0236]],
#        grad_fn=<AddBackward0>)
# Raw scene_graph: [(' teddy bear ', ' v:wear ', ' kimono ')]
# relation: (' teddy bear ', ' v:wear ', ' kimono ')
# len(relation) 3
# Processed relation: src = teddy bear, rel = wear, dst = kimono
# nodes: ['teddy bear', 'kimono']
# edges: [('teddy bear', 'wear', 'kimono')]
# node_to_id {'teddy bear': 0, 'kimono': 1}
# relation_to_id: {'wear': 0}
# src_nodes: [0]
# dst_nodes: [1]
# g (before adding self-loops): Graph(num_nodes=2, num_edges=1,
#       ndata_schemes={}
#       edata_schemes={})
# g (after adding self-loops): Graph(num_nodes=2, num_edges=3,
#       ndata_schemes={}
#       edata_schemes={})
# g with edge data: Graph(num_nodes=2, num_edges=3,
#       ndata_schemes={}
#       edata_schemes={'relation_type': Scheme(shape=(), dtype=torch.int64)})
# logits: tensor([[-0.0119,  0.0727, -0.0471,  ...,  0.0765, -0.0482,  0.0250],
#         [-0.0119,  0.0727, -0.0471,  ...,  0.0765, -0.0482,  0.0250]],
#        grad_fn=<AddBackward0>)
# Raw scene_graph: [(' train ', ' v:pass through ', ' arch ) ', ' ( bridge ', ' is ', ' stone ) ', ' ( train ', ' v:pass under ', ' bridge ')]
# relation: (' train ', ' v:pass through ', ' arch ) ', ' ( bridge ', ' is ', ' stone ) ', ' ( train ', ' v:pass under ', ' bridge ')
# len(relation) 9
# Processed relation: src = train, rel = pass through, dst = arch
# Processed relation: src = bridge, rel = is, dst = stone
# Processed relation: src = train, rel = pass under, dst = bridge
# nodes: ['stone', 'bridge', 'arch', 'train']
# edges: [('train', 'pass through', 'arch'), ('bridge', 'is', 'stone'), ('train', 'pass under', 'bridge')]
# node_to_id {'stone': 0, 'bridge': 1, 'arch': 2, 'train': 3}
# relation_to_id: {'pass through': 0, 'is': 1, 'pass under': 2}
# src_nodes: [3, 1, 3]
# dst_nodes: [2, 0, 1]
# g (before adding self-loops): Graph(num_nodes=4, num_edges=3,
#       ndata_schemes={}
#       edata_schemes={})
# g (after adding self-loops): Graph(num_nodes=4, num_edges=7,
#       ndata_schemes={}
#       edata_schemes={})
# g with edge data: Graph(num_nodes=4, num_edges=7,
#       ndata_schemes={}
#       edata_schemes={'relation_type': Scheme(shape=(), dtype=torch.int64)})
# logits: tensor([[-0.0110,  0.0726, -0.0462,  ...,  0.0738, -0.0451,  0.0285],
#         [-0.0110,  0.0726, -0.0462,  ...,  0.0738, -0.0451,  0.0285],
#         [-0.0110,  0.0726, -0.0462,  ...,  0.0738, -0.0451,  0.0285],
#         [-0.0110,  0.0726, -0.0462,  ...,  0.0738, -0.0451,  0.0285]],
#        grad_fn=<AddBackward0>)
# Raw scene_graph: [(' boys ', ' is ', ' 3 ) ', ' ( boys ', ' v:climb ', ' hill ')]
# relation: (' boys ', ' is ', ' 3 ) ', ' ( boys ', ' v:climb ', ' hill ')
# len(relation) 6
# Processed relation: src = boys, rel = is, dst = 3
# Processed relation: src = boys, rel = climb, dst = hill
# nodes: ['boys', 'hill', '3']
# edges: [('boys', 'is', '3'), ('boys', 'climb', 'hill')]
# node_to_id {'boys': 0, 'hill': 1, '3': 2}
# relation_to_id: {'is': 0, 'climb': 1}
# src_nodes: [0, 0]
# dst_nodes: [2, 1]
# g (before adding self-loops): Graph(num_nodes=3, num_edges=2,
#       ndata_schemes={}
#       edata_schemes={})
# g (after adding self-loops): Graph(num_nodes=3, num_edges=5,
#       ndata_schemes={}
#       edata_schemes={})
# g with edge data: Graph(num_nodes=3, num_edges=5,
#       ndata_schemes={}
#       edata_schemes={'relation_type': Scheme(shape=(), dtype=torch.int64)})
# logits: tensor([[-0.0101,  0.0720, -0.0449,  ...,  0.0726, -0.0423,  0.0327],
#         [-0.0101,  0.0720, -0.0449,  ...,  0.0726, -0.0423,  0.0327],
#         [-0.0101,  0.0720, -0.0449,  ...,  0.0726, -0.0423,  0.0327]],
#        grad_fn=<AddBackward0>)
# Raw scene_graph: [(' television set ', ' v:play ', ' baseball game ')]
# relation: (' television set ', ' v:play ', ' baseball game ')
# len(relation) 3
# Processed relation: src = television set, rel = play, dst = baseball game
# nodes: ['television set', 'baseball game']
# edges: [('television set', 'play', 'baseball game')]
# node_to_id {'television set': 0, 'baseball game': 1}
# relation_to_id: {'play': 0}
# src_nodes: [0]
# dst_nodes: [1]
# g (before adding self-loops): Graph(num_nodes=2, num_edges=1,
#       ndata_schemes={}
#       edata_schemes={})
# g (after adding self-loops): Graph(num_nodes=2, num_edges=3,
#       ndata_schemes={}
#       edata_schemes={})
# g with edge data: Graph(num_nodes=2, num_edges=3,
#       ndata_schemes={}
#       edata_schemes={'relation_type': Scheme(shape=(), dtype=torch.int64)})
# logits: tensor([[-0.0087,  0.0716, -0.0430,  ...,  0.0719, -0.0397,  0.0357],
#         [-0.0087,  0.0716, -0.0430,  ...,  0.0719, -0.0397,  0.0357]],
#        grad_fn=<AddBackward0>)
# Raw scene_graph: [(' cat ', ' in ', ' sink ')]
# relation: (' cat ', ' in ', ' sink ')
# len(relation) 3
# Processed relation: src = cat, rel = in, dst = sink
# nodes: ['sink', 'cat']
# edges: [('cat', 'in', 'sink')]
# node_to_id {'sink': 0, 'cat': 1}
# relation_to_id: {'in': 0}
# src_nodes: [1]
# dst_nodes: [0]
# g (before adding self-loops): Graph(num_nodes=2, num_edges=1,
#       ndata_schemes={}
#       edata_schemes={})
# g (after adding self-loops): Graph(num_nodes=2, num_edges=3,
#       ndata_schemes={}
#       edata_schemes={})
# g with edge data: Graph(num_nodes=2, num_edges=3,
#       ndata_schemes={}
#       edata_schemes={'relation_type': Scheme(shape=(), dtype=torch.int64)})
# logits: tensor([[-0.0074,  0.0702, -0.0417,  ...,  0.0710, -0.0384,  0.0389],
#         [-0.0074,  0.0702, -0.0417,  ...,  0.0710, -0.0384,  0.0389]],
#        grad_fn=<AddBackward0>)
# Raw scene_graph: [(' water ', ' on ', ' ground ')]
# relation: (' water ', ' on ', ' ground ')
# len(relation) 3
# Processed relation: src = water, rel = on, dst = ground
# nodes: ['ground', 'water']
# edges: [('water', 'on', 'ground')]
# node_to_id {'ground': 0, 'water': 1}
# relation_to_id: {'on': 0}
# src_nodes: [1]
# dst_nodes: [0]
# g (before adding self-loops): Graph(num_nodes=2, num_edges=1,
#       ndata_schemes={}
#       edata_schemes={})
# g (after adding self-loops): Graph(num_nodes=2, num_edges=3,
#       ndata_schemes={}
#       edata_schemes={})
# g with edge data: Graph(num_nodes=2, num_edges=3,
#       ndata_schemes={}
#       edata_schemes={'relation_type': Scheme(shape=(), dtype=torch.int64)})
# logits: tensor([[-0.0058,  0.0682, -0.0427,  ...,  0.0695, -0.0388,  0.0426],
#         [-0.0058,  0.0682, -0.0427,  ...,  0.0695, -0.0388,  0.0426]],
#        grad_fn=<AddBackward0>)
# Raw scene_graph: [(' buildings ', ' v:line ', ' street ')]
# relation: (' buildings ', ' v:line ', ' street ')
# len(relation) 3
# Processed relation: src = buildings, rel = line, dst = street
# nodes: ['buildings', 'street']
# edges: [('buildings', 'line', 'street')]
# node_to_id {'buildings': 0, 'street': 1}
# relation_to_id: {'line': 0}
# src_nodes: [0]
# dst_nodes: [1]
# g (before adding self-loops): Graph(num_nodes=2, num_edges=1,
#       ndata_schemes={}
#       edata_schemes={})
# g (after adding self-loops): Graph(num_nodes=2, num_edges=3,
#       ndata_schemes={}
#       edata_schemes={})
# g with edge data: Graph(num_nodes=2, num_edges=3,
#       ndata_schemes={}
#       edata_schemes={'relation_type': Scheme(shape=(), dtype=torch.int64)})
# logits: tensor([[-0.0043,  0.0668, -0.0444,  ...,  0.0682, -0.0412,  0.0459],
#         [-0.0043,  0.0668, -0.0444,  ...,  0.0682, -0.0412,  0.0459]],
#        grad_fn=<AddBackward0>)
# Raw scene_graph: [(' road ', ' v:have ', ' dirt ) ', ' ( road ', ' v:have ', ' grass ')]
# relation: (' road ', ' v:have ', ' dirt ) ', ' ( road ', ' v:have ', ' grass ')
# len(relation) 6
# Processed relation: src = road, rel = have, dst = dirt
# Processed relation: src = road, rel = have, dst = grass
# nodes: ['dirt', 'road', 'grass']
# edges: [('road', 'have', 'dirt'), ('road', 'have', 'grass')]
# node_to_id {'dirt': 0, 'road': 1, 'grass': 2}
# relation_to_id: {'have': 1}
# src_nodes: [1, 1]
# dst_nodes: [0, 2]
# g (before adding self-loops): Graph(num_nodes=3, num_edges=2,
#       ndata_schemes={}
#       edata_schemes={})
# g (after adding self-loops): Graph(num_nodes=3, num_edges=5,
#       ndata_schemes={}
#       edata_schemes={})
# g with edge data: Graph(num_nodes=3, num_edges=5,
#       ndata_schemes={}
#       edata_schemes={'relation_type': Scheme(shape=(), dtype=torch.int64)})
# logits: tensor([[-0.0022,  0.0639, -0.0444,  ...,  0.0676, -0.0419,  0.0479],
#         [-0.0022,  0.0639, -0.0444,  ...,  0.0676, -0.0419,  0.0479],
#         [-0.0022,  0.0639, -0.0444,  ...,  0.0676, -0.0419,  0.0479]],
#        grad_fn=<AddBackward0>)
# Raw scene_graph: [(' phones ', ' on ', ' table ) ', ' ( phones ', ' is ', ' 3 ')]
# relation: (' phones ', ' on ', ' table ) ', ' ( phones ', ' is ', ' 3 ')
# len(relation) 6
# Processed relation: src = phones, rel = on, dst = table
# Processed relation: src = phones, rel = is, dst = 3
# nodes: ['table', 'phones', '3']
# edges: [('phones', 'on', 'table'), ('phones', 'is', '3')]
# node_to_id {'table': 0, 'phones': 1, '3': 2}
# relation_to_id: {'on': 0, 'is': 1}
# src_nodes: [1, 1]
# dst_nodes: [0, 2]
# g (before adding self-loops): Graph(num_nodes=3, num_edges=2,
#       ndata_schemes={}
#       edata_schemes={})
# g (after adding self-loops): Graph(num_nodes=3, num_edges=5,
#       ndata_schemes={}
#       edata_schemes={})
# g with edge data: Graph(num_nodes=3, num_edges=5,
#       ndata_schemes={}
#       edata_schemes={'relation_type': Scheme(shape=(), dtype=torch.int64)})
# logits: tensor([[-0.0017,  0.0596, -0.0450,  ...,  0.0663, -0.0425,  0.0497],
#         [-0.0017,  0.0596, -0.0450,  ...,  0.0663, -0.0425,  0.0497],
#         [-0.0017,  0.0596, -0.0450,  ...,  0.0663, -0.0425,  0.0497]],
#        grad_fn=<AddBackward0>)
# Raw scene_graph: [(' clock ', ' on ', ' tower ')]
# relation: (' clock ', ' on ', ' tower ')
# len(relation) 3
# Processed relation: src = clock, rel = on, dst = tower
# nodes: ['tower', 'clock']
# edges: [('clock', 'on', 'tower')]
# node_to_id {'tower': 0, 'clock': 1}
# relation_to_id: {'on': 0}
# src_nodes: [1]
# dst_nodes: [0]
# g (before adding self-loops): Graph(num_nodes=2, num_edges=1,
#       ndata_schemes={}
#       edata_schemes={})
# g (after adding self-loops): Graph(num_nodes=2, num_edges=3,
#       ndata_schemes={}
#       edata_schemes={})
# g with edge data: Graph(num_nodes=2, num_edges=3,
#       ndata_schemes={}
#       edata_schemes={'relation_type': Scheme(shape=(), dtype=torch.int64)})
# logits: tensor([[-0.0019,  0.0552, -0.0443,  ...,  0.0638, -0.0422,  0.0508],
#         [-0.0019,  0.0552, -0.0443,  ...,  0.0638, -0.0422,  0.0508]],
#        grad_fn=<AddBackward0>)
# Raw scene_graph: [(' motorcycle ', ' in front of ', ' building ) ', ' ( motorcycle ', ' is ', ' parked ')]
# relation: (' motorcycle ', ' in front of ', ' building ) ', ' ( motorcycle ', ' is ', ' parked ')
# len(relation) 6
# Processed relation: src = motorcycle, rel = in front of, dst = building
# Processed relation: src = motorcycle, rel = is, dst = parked
# nodes: ['parked', 'building', 'motorcycle']
# edges: [('motorcycle', 'in front of', 'building'), ('motorcycle', 'is', 'parked')]
# node_to_id {'parked': 0, 'building': 1, 'motorcycle': 2}
# relation_to_id: {'in front of': 0, 'is': 1}
# src_nodes: [2, 2]
# dst_nodes: [1, 0]
# g (before adding self-loops): Graph(num_nodes=3, num_edges=2,
#       ndata_schemes={}
#       edata_schemes={})
# g (after adding self-loops): Graph(num_nodes=3, num_edges=5,
#       ndata_schemes={}
#       edata_schemes={})
# g with edge data: Graph(num_nodes=3, num_edges=5,
#       ndata_schemes={}
#       edata_schemes={'relation_type': Scheme(shape=(), dtype=torch.int64)})
# logits: tensor([[-0.0008,  0.0524, -0.0432,  ...,  0.0603, -0.0414,  0.0523],
#         [-0.0008,  0.0524, -0.0432,  ...,  0.0603, -0.0414,  0.0523],
#         [-0.0008,  0.0524, -0.0432,  ...,  0.0603, -0.0414,  0.0523]],
#        grad_fn=<AddBackward0>)
# Epoch 10/10, Loss: 79853.9556
# Checkpoint saved at epoch 10
